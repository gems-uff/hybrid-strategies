# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import database
from hover_graph import HoverGraph as Graph
from snowballing.operations import reload, compare_str, load_work_map_all_years
from snowballing.dbmanager import set_attribute
reload()
import pandas as pd

import math
def isnan(num):
    if isinstance(num, str):
        return False
    return math.isnan(num)
ratio = 0.9
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
pd.set_option('display.max_colwidth', -1)
todo = []

# %% [markdown]
# # Eng village

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "Eng village",  header=None)
df
# Out:
#                                                                                                                                              0
# 0   An approach to support the strategic alignment of software process improvement programs
# 1   Software engineering strategies: Aligning software process improvement with strategic goals
# 2   Software process improvement: Supporting the linking of the software and the business strategies
# 3   Critical success factors in software process improvement: A systematic review
# 4   Software process improvement for the airline industry
# 5   Tutorial: Business IT alignment using the GQM+strategies&reg approach
# 6   Linking software life cycle activities with product strategy and economics: Extending ISO/IEC 12207 with product management best practices
# 7   Using strategic planning for selection of SPI processes: An experience report
# 8   Application of GQM+Strategies&reg in the Japanese space industry
# 9   A sociotechnical approach towards alignment
# 10  A comparative study of SPI approaches with ProPAM
# 11  Aligning corporate and IT goals and strategies in the oil and gas industry
# 12  Defining and monitoring strategically aligned software improvement goals

# %%
key = "elcompendex2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey)
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
            
    if top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# - becker2008a ['elcompendex2015']
# - plösch2011a ['elcompendex2015']
# - albuquerque2009a ['elcompendex2015']
# - bayona2012a ['elcompendex2015']
# - zalzala2010a ['elcompendex2015']
# - heidrich2012a ['elcompendex2015']
# - stallinger2011a ['elcompendex2015']
# - vieira2009a ['elcompendex2015']
# - taxen2005a ['elcompendex2015']
# - martins2007a ['elcompendex2015']
# - basili2013a ['elcompendex2015']
# - barreto2010a ['elcompendex2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Application of GQM+Strategies&amp;reg in the Japanese space industry</td>
#       <td>0.8936170212765957 - kaneko2011a<br>0.6268656716417911 - lópez2016a<br>0.6259541984732825 - cocozza2014a<br>0.5652173913043478 - basili2013a<br>0.5565217391304348 - mandić2012b</td>
#       <td>elcompendex2015</td>
#     </tr>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 13

# %% [markdown]
# # IEEE

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "IEEE",  header=None)
df
# Out:
#                                                                                                                                                          0
# 0   Business Process Lines to Deal with the Variability
# 1   V-BPMI: A variability-oriented framework for web-based business processes modeling and implementation
# 2   Using a Reference Domain Ontology for Developing a Software Measurement Strategy for High Maturity Organizations
# 3   A Well-Founded Software Process Behavior Ontology to Support Business Goals Monitoring in High Maturity Software Organizations
# 4   Linking Software Development and Business Strategy Through Measurement
# 5   Using Goal-Oriented Requirements Engineering for Improving the Quality of ISO/IEC 15504 based Compliance Assessment Frameworks
# 6   A Survey of Service Identification Strategies
# 7   The Effect of Improving IT Standard in IT Governance
# 8   Organizational commitment towards software process improvement an irish software vses case study
# 9   A Method for Early Requirements Triage and Selection Utilizing Product Strategies
# 10  Dynamic process adaptation: A context-aware approach
# 11  A Product Line for Business Process Management
# 12  Software process improvement by example (SPIE)
# 13  A quantitative approach to software process management
# 14  A business goal-based approach to achieving systems engineering capability maturity
# 15  A Framework for the Elicitation and Analysis of Information Technology Service Requirements and Their Alignment with Enterprise Business Goals
# 16  Application of GQM+Strategies® in the Japanese Space Industry
# 17  Managing process inconsistency using viewpoints
# 18  Creating organic software maturity attitudes (COSMA) selected principles and activities for software maturity in small and medium software enterprises
# 19  Measuring and improving software process in China
# 20  Defect prevention through defect prediction: a case study at Infosys
# 21  Analyzing the Similarity among Software Projects to Improve Software Project Monitoring Processes
# 22  Calculating return on investment of training using process variation
# 23  Analysing Boundary Objects to Develop Results that Support Business Goals
# 24  Process Model of DSM Solution Development and Evolution for Small and Medium-Sized Software Companies
# 25  Context-awareness for adequate business process modelling
# 26  Towards Adaptability and Control for Knowledge-Intensive Business Processes: Declarative Configurable Process Specifications
# 27  Risk-Aware Business Process Modeling and Simulation Using XML Nets
# 28  Utilizing GQM+Strategies for an Organization-Wide Earned Value Analysis
# 29  Architecting for large-scale systematic component reuse
# 30  Do We Know Enough about Requirements Prioritization in Agile Projects: Insights from a Case Study
# 31  Conceptual simplicity meets organizational complexity: case study of a corporate metrics program
# 32  WDMES: A comprehensive measurement system for web application development
# 33  Towards a Metrics Suite for Measuring Composite Service Granularity Level Appropriateness
# 34  Fault Slip Through measurement in software development process
# 35  A customizable agile software Quality Assurance model
# 36  Engineering a Production Method for a Software Product Line
# 37  Factors for the Design of CMMI-Based Software Process Improvement Initiatives
# 38  Attaining Level 5 in CMM process maturity
# 39  Architecture-Centric Software Process for Pattern Based Software Reuse
# 40  Priorities of process improvement outcomes based on process capability levels
# 41  The human-computer interface is the system; a plea for a poor man's HCI component in software engineering curricula
# 42  Measuring Developers: Aligning Perspectives and Other Best Practices

# %%
key = "ieee2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey)
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
            
    if top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# - rolland2010a ['ieee2015']
# - angles2013a ['ieee2015']
# - barcellos2012a ['ieee2015']
# - barcellos2010a ['ieee2015']
# - basili2010a ['ieee2015']
# - rifaut2008a ['ieee2015']
# - cai2011a ['ieee2015']
# - park2006a ['ieee2015']
# - basri2010a ['ieee2015']
# - khurum2007a ['ieee2015']
# - nunes2011a ['ieee2015']
# - gimenes2008a ['ieee2015']
# - brebner1998a ['ieee2015']
# - debou1994b ['ieee2015']
# - waina2001a ['ieee2015']
# - zowghi2010a ['ieee2015']
# - sommerville1999a ['ieee2015']
# - grechenig2004a ['ieee2015']
# - wang2005a ['ieee2015']
# - mohapatra2001a ['ieee2015']
# - barreto2010b ['ieee2015']
# - matalonga2012a ['ieee2015']
# - ponisio2008a ['ieee2015']
# - koznov2011a ['ieee2015']
# - saidani2009a ['ieee2015']
# - rychkova2011a ['ieee2015']
# - betz2011a ['ieee2015']
# - mandić2010a ['ieee2015']
# - griss1999a ['ieee2015']
# - racheva2010a ['ieee2015']
# - herbsleb1998a ['ieee2015']
# - mazinanian2012a ['ieee2015']
# - khoshkbarforoushha2010a ['ieee2015']
# - duka2010a ['ieee2015']
# - hongying2011a ['ieee2015']
# - chastek2011a ['ieee2015']
# - dounos2010a ['ieee2015']
# - software2002a ['ieee2015']
# - hong2009a ['ieee2015']
# - varkoi2001a ['ieee2015']
# - veer2001a ['ieee2015']
# - umarji2009b ['ieee2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Application of GQM+Strategies® in the Japanese Space Industry</td>
#       <td>0.8695652173913043 - kaneko2011a<br>0.6412213740458015 - lópez2016a<br>0.640625 - cocozza2014a<br>0.5777777777777777 - basili2013a<br>0.5714285714285714 - mandić2012b</td>
#       <td>ieee2015</td>
#     </tr>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 43

# %% [markdown]
# # Scopus

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "SCOPUS",  header=None)
df
# Out:
#                                                                                                                                                                                                                                0
# 0   Critical success factors in software process improvement: A systematic review
# 1   Application of GQM+Strategies® in the Japanese space industry
# 2   Software engineering strategies: Aligning software process improvement with strategic goals
# 3   Linking software life cycle activities with product strategy and economics: Extending ISO/IEC 12207 with product management best practices
# 4   Alignment between the business strategy and the software processes improvement: A roadmap for the implementation [Alinhamento entre estratégia de negócios e melhoria de processos de software: Um roteiro de implementação]
# 5   Integration of strategic management, process improvement and quantitative measurement for managing the competitiveness of software engineering organizations
# 6   Software process improvement for the airline industry
# 7   Empirical evaluation of selected best practices in implementation of software process improvement
# 8   Software process improvement: Supporting the linking of the software and the business strategies
# 9   Using strategic planning for selection of SPI processes: An experience report
# 10  An approach to support the strategic alignment of software process improvement programs
# 11  A comparative study of SPI approaches with ProPAM
# 12  A low-overhead method for software process appraisal
# 13  Demanding change: How to remain in business despite IT
# 14  SPI: 'I can't get no satisfaction' - Directing process improvement to meet business needs

# %%
key = "scopus2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey)
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
            
    if top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# - bayona2012a ['scopus2015']
# - plösch2011a ['scopus2015']
# - stallinger2011a ['scopus2015']
# - asato2011a ['scopus2015']
# - guzmán2010a ['scopus2015']
# - zalzala2010a ['scopus2015']
# - galinac2009a ['scopus2015']
# - albuquerque2009a ['scopus2015']
# - vieira2009a ['scopus2015']
# - becker2008a ['scopus2015']
# - martins2007a ['scopus2015']
# - wilkie2007a ['scopus2015']
# - veryard1998a ['scopus2015']
# - reiblein1997a ['scopus2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Application of GQM+Strategies® in the Japanese space industry</td>
#       <td>0.8695652173913043 - kaneko2011a<br>0.6412213740458015 - lópez2016a<br>0.640625 - cocozza2014a<br>0.5777777777777777 - basili2013a<br>0.5714285714285714 - mandić2012b</td>
#       <td>scopus2015</td>
#     </tr>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 15

# %% [markdown]
# # Springer

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "SPRINGER",  header=None)
df
# Out:
#                                                                                                                                                     0
# 0    An Instrument for Measuring the Key Factors of Success in Software Process Improvement
# 1    A case study comparing defect profiles of a reused framework and of applications reusing it
# 2    A case study on software risk analysis and planning in medical device development
# 3    A controlled experiment to assess the impact of system architectures on new system requirements
# 4    A critical look at ISO 9000 for software quality management
# 5    A flexible method for software effort estimation by analogy
# 6    A Guttman Scaling of CMM Level 2 Practices: Investigating the Implementation Sequences Underlying Software Engineering Maturity
# 7    A lightweight approach to software validation by comparing UML use cases with internal program documentation selected via call graphs
# 8    A multiple case study on risk-based testing in industry
# 9    A quality cost reduction model for large-scale software development
# 10   A quality driven extension to the QVT-relations transformation language
# 11   A reference framework for process-oriented software development organizations
# 12   A research framework for building SPI proposals in small organizations: the COMPETISOFT experience
# 13   A socio-technical approach to improving the systems development process
# 14   A strategy for preparing software organizations for statistical process control
# 15   A test case refactoring approach for pattern-based software development
# 16   Adoption and use of cloud-based testing in practice
# 17   An architecture process maturity model of software product line engineering
# 18   An elicitation instrument for operationalising GQM+Strategies (GQM+S-EI)
# 19   An empirical study of variations in COTS-based software development processes in the Norwegian IT industry
# 20   An empirically based terminology and taxonomy for global software engineering
# 21   An Ethnographic Study of XP Practice
# 22   An industrial case study in reconstructing requirements views
# 23   An Industrial Case Study of Immediate Benefits of Requirements Engineering Process Improvement at the Australian Center for Unisys Software
# 24   An organizational maturity model of software product line engineering
# 25   An Overview of Process Technology Activities at the Software Engineering Institute
# 26   Assessing the effects of introducing a new software development process: a methodological description
# 27   Automatic Verification of Static Policies on Software Process Models
# 28   Benchmarking k-nearest neighbour imputation with homogeneous Likert data
# 29   Can the case for CASE technology be advanced by Process Improvement?
# ..                                                                    ...
# 111  Software and systems engineering process capability in the South Australian defence industry
# 112  Software Evolution and Software Evolution Processes
# 113  Software process improvement in small and medium software enterprises: a systematic review
# 114  Software quality management in turbulent times – are there alternatives to process oriented software quality management?
# 115  Software SMEs’ unofficial readiness for CMMI®-based software process improvement
# 116  Standardized code quality benchmarking for improving software maintainability
# 117  Strengths and barriers behind the successful agile deployment—insights from the three software intensive companies in Finland
# 118  Studying Software Engineers: Data Collection Techniques for Software Field Studies
# 119  Supporting multiple perspectives in feature-based configuration
# 120  Supporting Semantic Diversity in the Relational Data Model: The Case of Multi-Face Attributes
# 121  Test case prioritization: a systematic mapping study
# 122  The effect of moving from a plan-driven to an incremental software development approach with agile practices
# 123  The effectiveness of test-driven development: an industrial case study
# 124  The impact of agile practices on communication in software development
# 125  The Internal Consistencies of the 1987 SEI Maturity Questionnaire and the SPICE Capability Dimension
# 126  The kanban approach, between agility and leanness: a systematic review
# 127  The role of distances in requirements communication: a case study
# 128  The search for a research method for studying OSS process innovation
# 129  The use of an enterprise ontology to support knowledge management in software development environments
# 130  The value of a certified quality management system: the perception of internal developers
# 131  Theories, tools and research methods in program comprehension: past, present and future
# 132  Three Process Perspectives: Organizations, Teams, and People
# 133  Typology of database quality factors
# 134  Understanding cost drivers of software evolution: a quantitative and qualitative investigation of change effort in two evolving software systems
# 135  Understanding the gap between software process practices and actual practice in very small companies
# 136  Using text clustering to predict defect resolution time: a conceptual replication and an evaluation of prediction accuracy
# 137  Value Creation in a Network: The Role of Pricing and Revenue Optimization and Enterprise Profit OptimizationTM
# 138  Virtual Software Engineering Laboratories in Support of Trade-off Analyses
# 139  Virtual software team project management
# 140  Waste identification and elimination in information technology organizations
#
# [141 rows x 1 columns]

# %%
key = "springer2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey, int(getattr(w, key, 0)))
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
    
    if top5[0][0] >= 0.8 and top5[0][-1]:
        print(">", top5[0][1], keys)
    elif top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# > dybå2000a ['springer2015']
# > gupta2009a ['springer2015']
# > lindholm2014a ['springer2015']
# > ferrari2010a ['springer2015']
# > stelzer1997a ['springer2015']
# > li2007a ['springer2015']
# > bilotta1998a ['springer2015']
# > funkhouser2008a ['springer2015']
# > felderer2014a ['springer2015']
# > grbac2015a ['springer2015']
# > drago2015a ['springer2015']
# > fernandes2005a ['springer2015']
# > pino2016a ['springer2015']
# > patnayakuni2010a ['springer2015']
# > barcellos2013a ['springer2015']
# > chu2012a ['springer2015']
# > riungu2016a ['springer2015']
# > ahmed2011a ['springer2015']
# > petersen2015a ['springer2015']
# > li2006b ['springer2015']
# > smite2014a ['springer2015']
# > sharp2004a ['springer2015']
# > lormans2008a ['springer2015']
# > damian2004a ['springer2015']
# > ahmed2010a ['springer2015']
# > christie1998a ['springer2015']
# > nilsson2015a ['springer2015']
# > reis2002a ['springer2015']
# > jönsson2006a ['springer2015']
# > love1998a ['springer2015']
# > humphrey1992a ['springer2015']
# > bjarnason2014a ['springer2015']
# > benediktsson2003a ['springer2015']
# > chatterji2016a ['springer2015']
# > karahasanoviæ2005a ['springer2015']
# > abrahamsson2002a ['springer2015']
# > shin2016a ['springer2015']
# > pareto2012b ['springer2015']
# > gasston1999a ['springer2015']
# > dittrich2008a ['springer2015']
# > prikladnicki2014a ['springer2015']
# > bowes2014a ['springer2015']
# > osei2008a ['springer2015']
# > giraudo2003a ['springer2015']
# > hoda2012a ['springer2015']
# > ebert2002a ['springer2015']
# > smite2010a ['springer2015']
# > siakas2002a ['springer2015']
# > raffo1999b ['springer2015']
# > gholami2014a ['springer2015']
# > trienekens2009a ['springer2015']
# > williams2014a ['springer2015']
# > lindvall2007a ['springer2015']
# > koch2008a ['springer2015']
# > lepmets2012b ['springer2015']
# > osterweil2009a ['springer2015']
# > saiedian1996a ['springer2015']
# > moe2014a ['springer2015']
# > beirne1997a ['springer2015']
# > runeson2009a ['springer2015']
# > braun2014a ['springer2015']
# > jabangwe2015a ['springer2015']
# > baldassarre2012a ['springer2015']
# > garc2010a ['springer2015']
# > diirr2014a ['springer2015']
# > ebert1999c ['springer2015']
# > rose2015a ['springer2015']
# > cocchio1999a ['springer2015']
# > samoilenko2008a ['springer2015']
# > karlström2006a ['springer2015']
# > maurer2002a ['springer2015']
# > felderer2014b ['springer2015']
# > humphrey1995b ['springer2015']
# > jaliff1997a ['springer2015']
# > gleirscher2014a ['springer2015']
# > tarhan2011a ['springer2015']
# > sfetsos2006a ['springer2015']
# > kocaguneli2013a ['springer2015']
# > eito2014a ['springer2015']
# > khoshkbarforoushha2011a ['springer2015']
# > lee2014a ['springer2015']
# > hall2007a ['springer2015']
# > mäntylä2015a ['springer2015']
# > suominen2014a ['springer2015']
# > seo2013a ['springer2015']
# > kou2009a ['springer2015']
# > karlsson2007a ['springer2015']
# > maldonado2006a ['springer2015']
# > garcia2013a ['springer2015']
# > caglayan2015a ['springer2015']
# > mackie1997a ['springer2015']
# > deiters1998a ['springer2015']
# > henderson2002a ['springer2015']
# > harrison1997a ['springer2015']
# > francis1993a ['springer2015']
# > mohagheghi2007a ['springer2015']
# > ellis2013c ['springer2015']
# > kitchenham2010a ['springer2015']
# > jedlitschka2014a ['springer2015']
# > gorschek2006a ['springer2015']
# > mart2012a ['springer2015']
# > damian2005a ['springer2015']
# > goldin2015a ['springer2015']
# > kojima2008a ['springer2015']
# > caffery2009a ['springer2015']
# > felderer2016a ['springer2015']
# > lehman2001a ['springer2015']
# > goknil2011a ['springer2015']
# > grundy1998a ['springer2015']
# > dawson2003a ['springer2015']
# > leung1999a ['springer2015']
# > sitnikova2007a ['springer2015']
# > lehman2002a ['springer2015']
# > pino2008a ['springer2015']
# > mellis1998a ['springer2015']
# > iqbal2016a ['springer2015']
# > baggen2012a ['springer2015']
# > pikkarainen2012a ['springer2015']
# > lethbridge2005a ['springer2015']
# > hubaux2013a ['springer2015']
# > osei2004a ['springer2015']
# > catal2013a ['springer2015']
# > petersen2010a ['springer2015']
# > dog2011a ['springer2015']
# > pikkarainen2008a ['springer2015']
# > fusaro1998a ['springer2015']
# > al2015a ['springer2015']
# > bjarnason2017a ['springer2015']
# > prechelt2011a ['springer2015']
# > villela2005a ['springer2015']
# > robinson1996a ['springer2015']
# > storey2006a ['springer2015']
# > humphrey2002a ['springer2015']
# > hoxmeier1998a ['springer2015']
# > benestad2010a ['springer2015']
# > sánchez2016b ['springer2015']
# > assar2016a ['springer2015']
# > kalanidhi2001a ['springer2015']
# > münch2005a ['springer2015']
# > casey2010a ['springer2015']
# > al2014a ['springer2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 141

# %%
todo += result

# %% [markdown]
# # Web of Science

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "WEB OF SCIENCE",  header=None)
df
# Out:
#                                                                                                                                                               0
# 0  Designing a Strategic Measurement Program for Software Engineering Organizations: Discovering Difficulties and Problems
# 1  Critical Success Factors in Software Process Improvement: A Systematic Review
# 2  Linking Software Life Cycle Activities with Product Strategy and Economics: Extending ISO/IEC 12207 with Product Management Best Practices
# 3  Software Engineering Strategies: Aligning Software Process Improvement with Strategic Goals
# 4  Integration of strategic management, process improvement and quantitative measurement for managing the competitiveness of software engineering organizations
# 5  Software Process Improvement for the Airline Industry
# 6  Software Process Improvement: Supporting the Linking of the Software and the Business Strategies
# 7  AN APPROACH TO SUPPORT THE STRATEGIC ALIGNMENT OF SOFTWARE PROCESS IMPROVEMENT PROGRAMS
# 8  ProPAMet: A Metric for Process and Project Alignment
# 9  A comparative study of SPI approaches with ProPAM

# %%
key = "webofscience2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey, int(getattr(w, key, 0)))
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
    
    if top5[0][0] >= 0.8 and top5[0][-1]:
        print(">", top5[0][1], keys)
    elif top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# > mitrehernández2014a ['webofscience2015']
# > bayona2012a ['webofscience2015']
# > stallinger2011a ['webofscience2015']
# > plösch2011a ['webofscience2015']
# > guzmán2010a ['webofscience2015']
# > zalzala2010a ['webofscience2015']
# > albuquerque2009a ['webofscience2015']
# > becker2008a ['webofscience2015']
# > martins2008a ['webofscience2015']
# > martins2007a ['webofscience2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 90

# %% [markdown]
# # Science Direct

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "Science Direct",  header=None)
df
# Out:
#                                                                                                                                                                        0  \
# 0    A case study in innovative process improvement: code synthesis from formal specifications
# 1    A combination of the Mk-II function points software estimation method with the ADISSA methodology for systems analysis and design
# 2    A comparison of issues and advantages in agile and incremental development between state of the art and an industrial case
# 3    A decision support framework for metrics selection in goal-based measurement programs: GQM-DSFMS
# 4    A framework for software process deployment and evaluation
# 5    A general theory of software engineering: Balancing human
# 6    A lightweight framework for describing software practices
# 7    A Literature Review of Business/IT Alignment Strategies
# 8    A maturity model for the Spanish software industry based on ISO standards
# 9    A process capability based assessment model for software workforce in emergent software organizations
# 10   A Process Framework for Global Software Engineering Teams
# 11   A process reference model for managing living labs for ICT innovation: A proposal based on ISO/IEC 15504
# 12   A Product Line engineering practices model
# 13   A quality management based on the Quality Model life cycle
# 14   A rapid review method for extremely large corpora of literature: Applications to the domains of modelling
# 15   A survey of software engineering practices in Turkey
# 16   A survey of software testing practices in Canada
# 17   A systematic literature review on the industrial use of software process simulation
# 18   A systematic literature review to identify and classify software requirement errors
# 19   A systematic review and an expert survey on capabilities supporting multi product lines
# 20   A systematic review of domain analysis solutions for product lines
# 21   A systematic review of domain analysis tools
# 22   A systematic review of security requirements engineering
# 23   A tool for IT process construction
# 24   Actual vs. perceived effect of software engineering practices in the Italian industry
# 25   Adopting key lessons from agile manufacturing to agile software product development—A comparative study
# 26   Adoption of open source software in software-intensive organizations – A systematic literature review
# 27   Adoption of Social Media Networks by Indonesian SME: A Case Study
# 28   Agile requirements prioritization in large-scale outsourced system projects: An empirical study
# 29   Aligning Business Processes and Work Practices
# ..                                              ...
# 165  The forgotten promise of e-government maturity: Assessing responsiveness in the digital public sector
# 166  The impact of global dispersion on coordination
# 167  The impact of software process improvement on quality: in theory and practice
# 168  The Interplay between Requirements Relationships Knowledge and Requirements Change towards Software Project Success: An Assessment Using Partial Least Square (PLS)
# 169  The lean gap: A review of lean approaches to large-scale software systems development
# 170  The maturity of maturity model research: A systematic mapping study
# 171  The Process Enactment Tool Framework—Transformation of software process models to prepare enactment
# 172  The pursuit of cognition in manufacturing organizations
# 173  The role of the technology barometer in assessing the performance of the national innovation system
# 174  The Sensemaking-Coevolution-Implementation Theory of software design
# 175  The situational factors that affect the software development process: Towards a comprehensive reference framework
# 176  To what extent can maintenance problems be predicted by code smell detection? – An empirical study
# 177  Tool support for systems emergence: A multimedia CASE tool
# 178  Towards a New Approach to Supporting Top Managers in SPI Organizational Change Management
# 179  Towards a theoretical framework of SPI success factors for small and medium web companies
# 180  Understanding developer and manager perceptions of function points and source lines of code
# 181  Understanding reuse of software examples: A case study of prejudice in a community of practice
# 182  Understanding the characteristics of quality for software engineering processes: A Grounded Theory investigation
# 183  Understanding the effects of requirements volatility in software engineering by using analytical modeling and software process simulation
# 184  Understanding the use of an electronic process guide
# 185  Usage and usefulness of technical software documentation: An industrial case study
# 186  Using a multi-method approach to understand Agile software product lines
# 187  Using an expert panel to validate a requirements process improvement model
# 188  Using CMMI together with agile software development: A systematic review
# 189  Using grounded theory to understand software process improvement: A study of Irish software product companies
# 190  Using Scrum to guide the execution of software process improvement in small organizations
# 191  Using the GQM paradigm to investigate influential factors for software process improvement
# 192  Validating the ISO/IEC 15504 measures of software development process capability
# 193  What are the roles of software product managers? An empirical investigation
# 194  What do software practitioners really think about project success: A cross-cultural comparison
#
#                   1
# 0    Science Direct
# 1    Science Direct
# 2    Science Direct
# 3    Science Direct
# 4    Science Direct
# 5    Science Direct
# 6    Science Direct
# 7    Science Direct
# 8    Science Direct
# 9    Science Direct
# 10   Science Direct
# 11   Science Direct
# 12   Science Direct
# 13   Science Direct
# 14   Science Direct
# 15   Science Direct
# 16   Science Direct
# 17   Science Direct
# 18   Science Direct
# 19   Science Direct
# 20   Science Direct
# 21   Science Direct
# 22   Science Direct
# 23   Science Direct
# 24   Science Direct
# 25   Science Direct
# 26   Science Direct
# 27   Science Direct
# 28   Science Direct
# 29   Science Direct
# ..              ...
# 165  Science Direct
# 166  Science Direct
# 167  Science Direct
# 168  Science Direct
# 169  Science Direct
# 170  Science Direct
# 171  Science Direct
# 172  Science Direct
# 173  Science Direct
# 174  Science Direct
# 175  Science Direct
# 176  Science Direct
# 177  Science Direct
# 178  Science Direct
# 179  Science Direct
# 180  Science Direct
# 181  Science Direct
# 182  Science Direct
# 183  Science Direct
# 184  Science Direct
# 185  Science Direct
# 186  Science Direct
# 187  Science Direct
# 188  Science Direct
# 189  Science Direct
# 190  Science Direct
# 191  Science Direct
# 192  Science Direct
# 193  Science Direct
# 194  Science Direct
#
# [195 rows x 2 columns]

# %%
key = "sciencedirect2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey, int(getattr(w, key, 0)))
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
    
    if top5[0][0] >= 0.8 and top5[0][-1]:
        print(">", top5[0][1], keys)
    elif top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# > garbett1999a ['sciencedirect2015']
# > shoval1997a ['sciencedirect2015']
# > petersen2009a ['sciencedirect2015']
# > gencel2013a ['sciencedirect2015']
# > ruiz2015a ['sciencedirect2015']
# > kirk2012a ['sciencedirect2015']
# > aversano2012a ['sciencedirect2015']
# > garzás2013a ['sciencedirect2015']
# > tanriover2015a ['sciencedirect2015']
# > richardson2012a ['sciencedirect2015']
# > garcíaguzmán2013a ['sciencedirect2015']
# > coallier2005a ['sciencedirect2015']
# > domínguezmayo2012b ['sciencedirect2015']
# > garousi2015a ['sciencedirect2015']
# > garousi2013a ['sciencedirect2015']
# > ali2014a ['sciencedirect2015']
# > walia2009a ['sciencedirect2015']
# > holl2012a ['sciencedirect2015']
# > khurum2009a ['sciencedirect2015']
# > lisboa2010a ['sciencedirect2015']
# > mellado2010a ['sciencedirect2015']
# > vanut2010a ['sciencedirect2015']
# > egorova2010a ['sciencedirect2015']
# > kettunen2009a ['sciencedirect2015']
# > hauge2010a ['sciencedirect2015']
# > sarosa2012a ['sciencedirect2015']
# > daneva2013a ['sciencedirect2015']
# > zacarias2012a ['sciencedirect2015']
# > vavpotic2009a ['sciencedirect2015']
# > darwish2008a ['sciencedirect2015']
# > krishnan1998a ['sciencedirect2015']
# > staples2007a ['sciencedirect2015']
# > carrington2005a ['sciencedirect2015']
# > delgado2014a ['sciencedirect2015']
# > hsiao2009a ['sciencedirect2015']
# > song2007a ['sciencedirect2015']
# > singh2012a ['sciencedirect2015']
# > chakravorty2014a ['sciencedirect2015']
# > li2011a ['sciencedirect2015']
# > kasoju2013a ['sciencedirect2015']
# > pino2010a ['sciencedirect2015']
# > meneklis2010a ['sciencedirect2015']
# > arcilla2013a ['sciencedirect2015']
# > trienekens2005a ['sciencedirect2015']
# > williams2010a ['sciencedirect2015']
# > pareto2012a ['sciencedirect2015']
# > fitzgerald2017a ['sciencedirect2015']
# > baca2013a ['sciencedirect2015']
# > baddoo2003a ['sciencedirect2015']
# > debou1994a ['sciencedirect2015']
# > orta2014a ['sciencedirect2015']
# > mitrehernández2014a ['sciencedirect2015']
# > kannabiran2011a ['sciencedirect2015']
# > gorla2010a ['sciencedirect2015']
# > turner2010a ['sciencedirect2015']
# > andersen2006a ['sciencedirect2015']
# > tüzün2015a ['sciencedirect2015']
# > galinac2009a ['sciencedirect2015']
# > holt2014a ['sciencedirect2015']
# > islam2012a ['sciencedirect2015']
# > dybå2008a ['sciencedirect2015']
# > ajila2007a ['sciencedirect2015']
# > nikula2010a ['sciencedirect2015']
# > kishore2006a ['sciencedirect2015']
# > rinkevics2013a ['sciencedirect2015']
# > babar2007b ['sciencedirect2015']
# > kluth2014a ['sciencedirect2015']
# > staples2007b ['sciencedirect2015']
# > khan2011a ['sciencedirect2015']
# > acher2013a ['sciencedirect2015']
# > lepmets2012a ['sciencedirect2015']
# > aversano2013a ['sciencedirect2015']
# > ibanez1996a ['sciencedirect2015']
# > lim2012a ['sciencedirect2015']
# > jacobs2007a ['sciencedirect2015']
# > berssaneti2015a ['sciencedirect2015']
# > niazi2009a ['sciencedirect2015']
# > jorgensen2001a ['sciencedirect2015']
# > lucio2012a ['sciencedirect2015']
# > bunse1998a ['sciencedirect2015']
# > sanchez2010a ['sciencedirect2015']
# > baskerville2014a ['sciencedirect2015']
# > weerd2010a ['sciencedirect2015']
# > draghici2012a ['sciencedirect2015']
# > habra2007a ['sciencedirect2015']
# > ng2012a ['sciencedirect2015']
# > mesquida2015b ['sciencedirect2015']
# > ng2015a ['sciencedirect2015']
# > faegri2010a ['sciencedirect2015']
# > aurum2008a ['sciencedirect2015']
# > coleman2008a ['sciencedirect2015']
# > jalali2014a ['sciencedirect2015']
# > karhu2009a ['sciencedirect2015']
# > magalhaes2015a ['sciencedirect2015']
# > rabiser2011a ['sciencedirect2015']
# > bjørnson2008a ['sciencedirect2015']
# > ding2014a ['sciencedirect2015']
# > wellisch2003a ['sciencedirect2015']
# > niessink2001a ['sciencedirect2015']
# > petersen2011b ['sciencedirect2015']
# > díazley2010a ['sciencedirect2015']
# > baddoo2002a ['sciencedirect2015']
# > mite2013a ['sciencedirect2015']
# > wohlin2013a ['sciencedirect2015']
# > fuggetta2003a ['sciencedirect2015']
# > heikkilä2015a ['sciencedirect2015']
# > fagerholm2015a ['sciencedirect2015']
# > fernandes2011a ['sciencedirect2015']
# > li2010a ['sciencedirect2015']
# > baskerville2011a ['sciencedirect2015']
# > fernandez2014a ['sciencedirect2015']
# > al2013b ['sciencedirect2015']
# > iden2011a ['sciencedirect2015']
# > hanssen2008a ['sciencedirect2015']
# > cater2006a ['sciencedirect2015']
# > lane2011a ['sciencedirect2015']
# > fontana2014a ['sciencedirect2015']
# > fontana2015a ['sciencedirect2015']
# > ebert1998a ['sciencedirect2015']
# > allué2013a ['sciencedirect2015']
# > riel2010a ['sciencedirect2015']
# > domínguezmayo2012a ['sciencedirect2015']
# > chan2002a ['sciencedirect2015']
# > kulk2008a ['sciencedirect2015']
# > verhoef2007a ['sciencedirect2015']
# > peters2008a ['sciencedirect2015']
# > xu2006a ['sciencedirect2015']
# > pernstål2015a ['sciencedirect2015']
# > gorschek2008a ['sciencedirect2015']
# > pérez2006a ['sciencedirect2015']
# > cruzes2011a ['sciencedirect2015']
# > damm2006b ['sciencedirect2015']
# > verner2014b ['sciencedirect2015']
# > ayala2011a ['sciencedirect2015']
# > hustad2014a ['sciencedirect2015']
# > unphon2010a ['sciencedirect2015']
# > paternoster2014a ['sciencedirect2015']
# > savolainen2012a ['sciencedirect2015']
# > na2007a ['sciencedirect2015']
# > ampatzoglou2010a ['sciencedirect2015']
# > roche1994a ['sciencedirect2015']
# > allison2007a ['sciencedirect2015']
# > müller2010a ['sciencedirect2015']
# > niazi2010a ['sciencedirect2015']
# > ianzen2013a ['sciencedirect2015']
# > sulayman2012a ['sciencedirect2015']
# > thompson1993a ['sciencedirect2015']
# > garcia2014a ['sciencedirect2015']
# > kellner1999a ['sciencedirect2015']
# > raffo1999a ['sciencedirect2015']
# > suomalainen2011a ['sciencedirect2015']
# > subramanian2007a ['sciencedirect2015']
# > garcia2010a ['sciencedirect2015']
# > cuenca2013a ['sciencedirect2015']
# > winter2010a ['sciencedirect2015']
# > marew2009a ['sciencedirect2015']
# > ebert1999a ['sciencedirect2015']
# > ebert1999b ['sciencedirect2015']
# > dolezel2015a ['sciencedirect2015']
# > chiu2007a ['sciencedirect2015']
# > chen2011a ['sciencedirect2015']
# > andersen2011a ['sciencedirect2015']
# > ashrafi2003a ['sciencedirect2015']
# > aziz2015a ['sciencedirect2015']
# > pernstal2013a ['sciencedirect2015']
# > wendler2012a ['sciencedirect2015']
# > kuhrmann2014a ['sciencedirect2015']
# > nobre2008a ['sciencedirect2015']
# > loikkanen2009a ['sciencedirect2015']
# > ralph2015a ['sciencedirect2015']
# > clarke2012b ['sciencedirect2015']
# > yamashita2013a ['sciencedirect2015']
# > king1997a ['sciencedirect2015']
# > herranz2013a ['sciencedirect2015']
# > sulayman2014a ['sciencedirect2015']
# > sheetz2009a ['sciencedirect2015']
# > barzilay2014a ['sciencedirect2015']
# > kroeger2014a ['sciencedirect2015']
# > ferreira2009a ['sciencedirect2015']
# > scott2002a ['sciencedirect2015']
# > garousi2015b ['sciencedirect2015']
# > silva2015b ['sciencedirect2015']
# > beecham2005a ['sciencedirect2015']
# > silva2015a ['sciencedirect2015']
# > coleman2007a ['sciencedirect2015']
# > pino2010b ['sciencedirect2015']
# > mashiko1997a ['sciencedirect2015']
# > emam2000b ['sciencedirect2015']
# > maglyas2013a ['sciencedirect2015']
# > pereira2008a ['sciencedirect2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A general theory of software engineering: Balancing human</td>
#       <td>0.76 - wohlin2015a - 1<br>0.6728971962616822 - mei2018a - 0<br>0.6666666666666666 - wirth2008a - 0<br>0.6422018348623854 - garousi2015a - 1<br>0.5964912280701754 - richardson2012a - 1</td>
#       <td>sciencedirect2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A rapid review method for extremely large corpora of literature: Applications to the domains of modelling</td>
#       <td>0.8823529411764706 - jahangirian2011a - 0<br>0.475 - campanai1995a - 0<br>0.4678362573099415 - aydin2002a - 0<br>0.46236559139784944 - vieira2014a - 0<br>0.4585987261146497 - türetken2007a - 0</td>
#       <td>sciencedirect2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Coding-error based defects in enterprise resource planning software: Prevention</td>
#       <td>0.8020304568527918 - woungang2012a - 0<br>0.5193370165745856 - villela2005a - 0<br>0.5161290322580645 - zhang2008d - 0<br>0.5161290322580645 - zhang2008d - 0<br>0.5161290322580645 - zhang2005a - 0</td>
#       <td>sciencedirect2015</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>portfolio decision-making in local governments: Rationality</td>
#       <td>0.7329192546583851 - nielsen2014a - 1<br>0.5384615384615384 - orta2014a - 1<br>0.5 - debou1994a - 1<br>0.496 - ivarsson2012a - 0<br>0.4883720930232558 - orlov2007a - 0</td>
#       <td>sciencedirect2015</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The impact of global dispersion on coordination</td>
#       <td>0.5662650602409639 - nguyenduc2015a - 0<br>0.5504587155963303 - kamel2009a - 0<br>0.5365853658536586 - khalifa2016a - 0<br>0.5299145299145299 - pikkarainen2008a - 0<br>0.5294117647058824 - nobre2008a - 1</td>
#       <td>sciencedirect2015</td>
#     </tr>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 192

# %%
todo += result

# %% [markdown]
# # ACM

# %%
xls = pd.ExcelFile("review.xls")
df = pd.read_excel(xls, "ACM",  header=None)
df
# Out:
#                                                                                                                                              0
# 0   Gauging acceptance of software metrics: Comparing perspectives of managers and developers
# 1   Brazilian public software: beyond sharing
# 2   The agile practices impact model: idea, concept, and application scenario
# 3   A pattern system of underlying theories for process improvement
# 4   Managing ERP configuration variants: an experience report
# 5   Using a functional size measurement procedure to evaluate the quality of models in MDD environments
# 6   Value­based software engineering: reinventing
# 7   An approach to identify commonalities in web application engineering for a web content  management system
# 8   Free/open source software development
# 9   Studying software organizations: in search of a method
# 10  Strategically balanced process adoption
# 11  A software process engineering approach to improving software team productivity using  socioeconomic mechanism design
# 12  A comprehensive product line scoping approach and its validation
# 13  Process­driven feature modeling for variability management of project environment configurations
# 14  Introducing usability activities into open source software development projects: a participative  approach
# 15  Enablers and inhibitors for speed with reuse
# 16  Consequences of business growth on software processes
# 17  An empirical study on the utility of formal routines to transfer knowledge and experience
# 18  Business impact of process improvements
# 19  Capturing business benefits from process improvement: four fallacies and what to do about them
# 20  Two's company, three's a crowd: a case study of crowdsourcing software development
# 21  Towards global market­driven software development processes: an industrial case study
# 22  An empirical study of industrial requirements engineering process assessment and improvement
# 23  Modeling business processes to generate artifacts for software development: a methodology
# 24  A multiple case study on the impact of pair programming on product quality
# 25  Key processes to start software process improvement in small companies
# 26  Relating requirements and feature configurations: a systematic approach
# 27  A process for driving the harmonization of models
# 28  Joint implicit alignment work of interaction designers and software developers
# 29  Software process reflexivity and business performance: initial results from an empirical study
# ..                                                                                             ...
# 70  Information needs for software development analytics
# 71  Some observations on software quality
# 72  Utilizing GQM+Strategies for business value analysis: an approach for evaluating business goals
# 73  Semantic representation of context models: a framework for analyzing and understanding
# 74  Writing and Reading Software Documentation: How the development process may affect  understanding
# 75  "Figure out how to code with the hands of others": recognizing cultural blind spots in global  software development
# 76  Optimizing IT process management
# 77  Free/open source software development: recent research results and emerging opportunities
# 78  On the use of machine­assisted knowledge discovery to analyze and reengineer measurement  frameworks
# 79  Balancing four factors in system development projects
# 80  E­government: exploring the different dimensions of challenges, implementation, and success factors
# 81  Agile in India: challenges and lessons learned
# 82  Migrating towards evolving software product lines: challenges of an SME in a core customer­ driven  industrial systems engineering context
# 83  SimPal: a design study on a framework for flexible safety­critical software development
# 84  The public software ecosystem: exploratory survey
# 85  In search of the sweet spot: agile open collaborative corporate software development
# 86  Using the IDEAL software process improvement model for the implementation of automotive  SPICE
# 87  Assessing team performance from a socio­technical congruence perspective
# 88  Trends and emerging areas of agile research: the report on XP2014 PhD symposium
# 89  Continuous software engineering and beyond: trends and challenges
# 90  Communication factors for speed and reuse in large­scale agile software development
# 91  Commitment development in software process improvement: critical misconceptions
# 92  Identifying the factors that influence task allocation in global software development: preliminary results
# 93  People management in software industry: the key to success
# 94  Surprise: user­controlled granular privacy and security for personal data in SmarterContext
# 95  Software reuse in agile development organizations: a conceptual management tool
# 96  The value of design rationale information
# 97  Product derivation for solution­driven product line engineering
# 98  Assessing capability for justice information sharing
# 99  Introducing TDD on a free libre open source software project: a simulation experiment
#
# [100 rows x 1 columns]

# %%
key = "acm2015"
result = []

for i, row in df.iterrows():
    top5 = sorted([
        (compare_str(row.iloc[0].lower(), w.name.lower()), metakey, int(getattr(w, key, 0)))
        for metakey, w in load_work_map_all_years()
    ], reverse=True, key=lambda x:x[0])[:5]
    
    keys = [key]
    
    if top5[0][0] >= 0.8 and top5[0][-1]:
        print(">", top5[0][1], keys)
    elif top5[0][0] >= ratio:
        print("-", top5[0][1], keys)
        for key in keys:
            set_attribute(top5[0][1], key, "1")
    else:
        result.append([
            row.iloc[0],
            "\n".join(" - ".join(map(str, x)) for x in top5),
            "\n".join(keys)
        ])

result
pretty_print(pd.DataFrame(result))
# Out:
# > umarji2009a ['acm2015']
# > alves2010a ['acm2015']
# > diebold2015a ['acm2015']
# > hilst2010a ['acm2015']
# > leitner2010a ['acm2015']
# > marín2013a ['acm2015']
# > boehm2003d ['acm2015']
# > souer2010a ['acm2015']
# > scacchi2007a ['acm2015']
# > srinivasan2010a ['acm2015']
# > esfahani2011a ['acm2015']
# > yilmaz2011a ['acm2015']
# > schmid2002a ['acm2015']
# > moser2010a ['acm2015']
# > rajanen2012a ['acm2015']
# > martini2012a ['acm2015']
# > nikitina2010a ['acm2015']
# > conradi2001a ['acm2015']
# > paulisch2008a ['acm2015']
# > bannerman2008a ['acm2015']
# > stol2014a ['acm2015']
# > jantunen2006a ['acm2015']
# > sommerville2005a ['acm2015']
# > aysolmaz2014a ['acm2015']
# > hulkko2005a ['acm2015']
# > pino2009c ['acm2015']
# > tun2009a ['acm2015']
# > pardo2010a ['acm2015']
# > brown2012a ['acm2015']
# > o2015a ['acm2015']
# > maheshwari2011a ['acm2015']
# > fagerholm2012a ['acm2015']
# > souer2008a ['acm2015']
# > ramsin2008a ['acm2015']
# > mkhomazi2011a ['acm2015']
# > boustedt2008a ['acm2015']
# > mcleod2011a ['acm2015']
# > luzuriaga2008a ['acm2015']
# > imtiaz2012a ['acm2015']
# > avila2007a ['acm2015']
# > lavazza2005a ['acm2015']
# > ferreira2007a ['acm2015']
# > komuro2006a ['acm2015']
# > zahedi2014a ['acm2015']
# > whitehead2007a ['acm2015']
# > duszynski2011a ['acm2015']
# > al2014b ['acm2015']
# > virtanen2013a ['acm2015']
# > shoemaker2003a ['acm2015']
# > oConnor2015a ['acm2015']
# > kirk2014a ['acm2015']
# > benestad2011a ['acm2015']
# > felderer2014c ['acm2015']
# > rech2011a ['acm2015']
# > becker2008b ['acm2015']
# > kautz2000a ['acm2015']
# > barcellos2013b ['acm2015']
# > desai2009a ['acm2015']
# > harter2000a ['acm2015']
# > daneva2001b ['acm2015']
# > mettler2009a ['acm2015']
# > chouseinoglou2012a ['acm2015']
# > alkadhi2014a ['acm2015']
# > macmahon2013a ['acm2015']
# > dybå2012a ['acm2015']
# > bourimi2014a ['acm2015']
# > wiesche2014a ['acm2015']
# > buse2012a ['acm2015']
# > ward1999a ['acm2015']
# > mandić2010b ['acm2015']
# > najar2009a ['acm2015']
# > boer2009a ['acm2015']
# > matthiesen2014a ['acm2015']
# > lee2010b ['acm2015']
# > scacchi2007b ['acm2015']
# > bhandari1995a ['acm2015']
# > subramanian2009a ['acm2015']
# > mishra2012a ['acm2015']
# > srinivasan2010b ['acm2015']
# > stallinger2011b ['acm2015']
# > notander2013a ['acm2015']
# > cardoso2013a ['acm2015']
# > theunissen2005a ['acm2015']
# > klendauer2012a ['acm2015']
# > falessi2014a ['acm2015']
# > fitzgerald2014a ['acm2015']
# > martini2013a ['acm2015']
# > abrahamsson2001b ['acm2015']
# > mahmood2015a ['acm2015']
# > mishra2010a ['acm2015']
# > muñoz2012a ['acm2015']
# > spoelstra2011a ['acm2015']
# > falessi2013a ['acm2015']
# > elsner2009a ['acm2015']
# > cresswell2007a ['acm2015']
# > turnu2004a ['acm2015']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Frontmatter (TOC, Letters, Election results, Software Reliability Resources, ICSE 2005)</td>
#       <td>0.46540880503144655 - virtanen2013a - 1<br>0.4642857142857143 - rus1999b - 0<br>0.45714285714285713 - hongying2011a - 0<br>0.4519774011299435 - hansen2004a - 0<br>0.45121951219512196 - marcus2005a - 0</td>
#       <td>acm2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Computing curricula 2001</td>
#       <td>0.43636363636363634 - cmmi2005a - 0<br>0.4 - caputo1999a - 0<br>0.3888888888888889 - kautz2000c - 0<br>0.3870967741935484 - wohlin2012h - 0<br>0.37735849056603776 - basili1994a - 0</td>
#       <td>acm2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Software process</td>
#       <td>0.7272727272727273 - emam2001b - 0<br>0.7111111111111111 - humphrey1989a - 0<br>0.6956521739130435 - armbrust2009a - 0<br>0.6956521739130435 - florac1999b - 0<br>0.6274509803921569 - humphrey1988a - 0</td>
#       <td>acm2015</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Assessing team performance from a socio­technical congruence perspective</td>
#       <td>0.496551724137931 - coleman2008a - 0<br>0.4900662251655629 - liu2006b - 0<br>0.48520710059171596 - jaramillo2016a - 0<br>0.4742268041237113 - ngwenyama2003a - 0<br>0.464 - mirna2014a - 0</td>
#       <td>acm2015</td>
#     </tr>
#   </tbody>
# </table>

# %%
reload()
len({w for _, w in load_work_map_all_years() if int(getattr(w, key, 0))})
# Out:
# 97

# %%
todo += result

# %%
len(todo)

# %%
df = pd.DataFrame(todo)

# %%
df.to_csv("../todo_francisco.csv")

# %%
df.to_excel("../todo_francisco.xlsx")
