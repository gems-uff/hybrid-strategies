# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import database
import xlrd
from hover_graph import HoverGraph as Graph
from snowballing.operations import reload, compare_str, load_work_map_all_years
from snowballing.dbmanager import set_attribute
reload()
import pandas as pd

import math
def isnan(num):
    if isinstance(num, str):
        return False
    return math.isnan(num)
ratio = 0.9
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
#pd.set_option('display.max_colwidth', -1)
todo = []

# %%
#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "scopus",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemScopus",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "ElCompendex",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemElCompendex",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "Springer",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemSpringer",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#Outro exemplo, mas sem hash e sem lower case

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(data.tolist())
print (lista1)
    
df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(data2.tolist())
    
print (lista2)

def intersection(lista1, lista2):
    lista3 = [value for value in lista1 if value in lista2]
    return lista3

print(intersection(lista1, lista2))

# %%
# Outro exemplo, mas sem o import.

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(data.tolist()))
print (lista1)

df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(tuple(data2.tolist()))
    
print (lista2)

def intersection(lista1, lista2):
    temp = set(lista2)
    lista3 = [value for value in lista1 if value in temp]
    return lista3

print(intersection(lista1, lista2))

# %%
df = pd.read_csv("springer.csv")

# %%
set(df.iloc[:,0].tolist())
# Out:
# {"'Go to the ant': Engineering principles from natural multi-agent systems",
#  '1.1.Grundlage, Methoden, Apparate, Reagentien, Automation, Datenverarbeitung',
#  '18th annual conference of the international society for computer aided surgery',
#  '1st International One Health Congress Abstracts',
#  '2012 HRS/EHRA/ECAS expert consensus statement on catheter and surgical ablation of atrial fibrillation: recommendations for patient selection, procedural techniques, patient management and follow-up, definitions, endpoints, and research trial design',
#  '3D Technology in Design and Production',
#  'A',
#  'A Business Rule Engine Applied to Egovernment Services Integration',
#  'A Case Study on the Impact of Refactoring on Quality and Productivity in an Agile Team',
#  'A Development Process for Usable Large Scale Interactive Critical Systems: Application to Satellite Ground Segments',
#  'A Digital Transparent Satellite Payload Concept for Personal Mobile Satellite Communications: A VLSI Technology Review',
#  'A Mapping of Individual Architecture Frameworks (GRAI, PERA, C4ISR, CIMOSA, ZACHMAN, ARIS) onto GERAM',
#  'A Model Driven Approach for XML Database Development',
#  'A Privacy Engineering Lifecycle Methodology',
#  'A Roadmap of Manufacturing System Evolution',
#  'A Software Framework for Building Biomedical Machine Learning Classifiers through Grid Computing Resources',
#  'A Systematic Review of Game Design Methods and Tools',
#  'A Web-Based System for Interface Management of Metro Equipment Engineering',
#  'A context management architecture for m-commerce applications',
#  'A decision support system for analysis of effects of timely fulfillment of customer demand in supply chain management practices',
#  'A decision-support framework for agile enterprise partnering',
#  'A dependency taxonomy for agile software development projects',
#  'A distributed internet-based framework for manufacturing planning',
#  'A domain-specific decision support system for knowledge discovery using association and text mining',
#  'A dynamic capabilities-based entrepreneurial theory of the multinational enterprise',
#  'A dynamic spectrum access network based on cognitive radio',
#  'A framework for intelligent design of manufacturing cells',
#  'A framework for strategy formulation in sustainable supply chains: a case study in the electric industry',
#  'A genetic algorithm for solving no-wait flexible flow lines with due window and job rejection',
#  'A history of AI and Law in 50 papers: 25\xa0years of the international conference on AI and Law',
#  'A holistic control architecture infrastructure for dynamic scheduling',
#  'A hybrid multi-criteria decision-making model for personnel selection in manufacturing systems',
#  'A journey to highly dynamic, self-adaptive service-based applications',
#  'A knowledge-based framework for extracting components in agile systems development',
#  'A model-driven approach to enabling change capability in SMEs',
#  'A multiagent supply chain planning and coordination architecture',
#  'A multiple case study on risk-based testing in industry',
#  'A multiple comparative study of test-with development product changes and their effects on team speed and product quality',
#  'A network approach for modeling and design of agile supply chains using a flexibility construct',
#  'A neural architecture for visual information processing',
#  'A new fuzzy network data envelopment analysis model for measuring the performance of agility in supply chains',
#  'A novel lifecycle model for Web-based application development in small and medium enterprises',
#  'A research framework for building SPI proposals in small organizations: the COMPETISOFT experience',
#  'A roadmap for implementing new manufacturing technology based on STEP-NC',
#  'A service innovation framework for start-up firms by integrating service experience engineering approach and capability maturity model',
#  'A service requirements engineering method for a digital service ecosystem',
#  'A study on PDAs for onboard applications and technologies and methodologies',
#  'A study to support agile methods more effectively through traceability',
#  'Abstracts',
#  'Abstracts der 6. Jahrestagung Deutsche Gesellschaft Interdisziplinäre Notfallaufnahme (DGINA) e. V.',
#  'Abstracts of Documents in This Supplement',
#  'Abstracts of the 16th International Congress of ESCAP European Society for Child and Adolescent Psychiatry',
#  'Acceptance Test Driven Planning',
#  'Acceptance Testing vs. Unit Testing: A Developer’s Perspective',
#  'Achieving CMMI Level 2 with Enhanced Extreme Programming Approach',
#  'Achieving agility through BRIDGE process model: an approach to integrate the agile and disciplined software development',
#  'Adapting SCRUM to the Italian Army: Methods and (Open) Tools',
#  'Adaptive shaping of two-cycle visible pulses using a flexible mirror',
#  'Advances in Measurement systems integration',
#  'Agency transformation – An interview with Carlos Gaviria of the Fifth Channel',
#  'Agile Development: Good Process or Bad Attitude?',
#  'Agile Entwicklung Web-basierter Systeme',
#  'Agile Meets CMMI: Culture Clash or Common Cause?',
#  'Agile Planning Processes',
#  'Agile Principles and Open Source Software Development: A Theoretical and Empirical Discussion',
#  'Agile Project Management Methods for ERP: How to Apply Agile Processes to Complex COTS Projects and Live to Tell about It',
#  'Agile Software Development with Open Source Software in a Hospital Environment – Case Study of an eCRF-System for Orthopaedical Studies',
#  'Agile User Experience Development in a Large Software Organization: Good Expertise but Limited Impact',
#  'Agile manufacturing: framework and its empirical validation',
#  'Agile methods for embedded systems development - a literature review and a mapping study',
#  'Agile product development through CAD and rapid prototyping technologies: an examination in a traditional pump-manufacturing company',
#  'Agile science: creating useful products for behavior change in the real world',
#  'Agile vs. structured distributed software development: A case study',
#  'Agility Measurements Mismatch: A Validation Study on Three Agile Team Assessments in Software Engineering',
#  'Agility appraisal for integrated supply chain using generalized trapezoidal fuzzy numbers set',
#  'Agility in Information Systems Development: A Three-Tiered Framework',
#  'An ANP-based assessment model for lean enterprise transformation',
#  'An Agile CMM',
#  'An Agile Customer-Centered Method: Rapid Contextual Design',
#  "An Integrated Framework for Service Quality, Customer Value, Satisfaction: Evidence from China's Telecommunication Industry",
#  'An Intelligent Data Integration Approach for Collaborative Project Management in Virtual Enterprises',
#  'An MPEG-7 scheme for semantic content modelling and filtering of digital video',
#  'An Overview of Manufacturing And Supply Systems Management',
#  'An agile operations management system for green factory',
#  'An approach to the software quality management',
#  'An efficient algorithm to solve a multi-objective robust aggregate production planning in an uncertain environment',
#  'An empirical study of the state of the practice and acceptance of model-driven engineering in four industrial cases',
#  'An empirically based terminology and taxonomy for global software engineering',
#  'An experience report on the verification of autonomic protocols in the cloud',
#  'An experiment on the effectiveness and efficiency of exploratory testing',
#  'An experimental investigation of personality types impact on pair effectiveness in pair programming',
#  'An integrated analytic network process with mixed-integer non-linear programming to supplier selection and order allocation',
#  'An integrated design methodology based on the use of group AHP-DEA approach for measuring lean tools efficiency with undesirable output',
#  'An integrated modeling method for assessment of quality systems applied to aerospace manufacturing supply chains',
#  'An integrated stochastic-fuzzy modeling approach for supply chain leanness evaluation',
#  'Analysis on critical success factors for agile manufacturing evaluation in original equipment manufacturing industry-an AHP approach',
#  'Application Systems in the Individual Business Functions',
#  'Application of Analytic Network Process for the Design of Flexible Manufacturing Systems',
#  'Application of green collaboration operation on network industry',
#  'Applied Number Theory in Computing/Cryptography',
#  'Architecturing large integrated complex information systems: an application to healthcare',
#  'Aricon Initiative: Barriers in Adopting the Virtual Enterprise Approach in the New Product Development (NPD) Context',
#  'Assessing Business Agility: A Multi-Industry Study in The Netherlands',
#  'Assessing agile methods: An empirical study',
#  'Assisting requirements analysts to find latent concerns with REAssistant',
#  'Astronomical Instruments and Techniques',
#  'Author’s Index',
#  'Automating Object-Oriented Software Development Methods',
#  'Autonomous Behaviour in Automated Manufacturing Systems',
#  'Balanced Automation',
#  'Bayesian networks for enhancement of requirements engineering: a literature review',
#  'Big data analytics in E-commerce: a systematic review and agenda for future research',
#  'Blending Scrum practices and CMMI project management process areas',
#  'Business And Strategic Planning',
#  'Business model metrics: an open repository',
#  'Business process management with\xa0the\xa0user\xa0requirements notation',
#  'C',
#  'CBRFlow: Enabling Adaptive Workflow Management Through Conversational Case-Based Reasoning',
#  'CDM predictions of creep damage initiation and growth in ferritic steel weldments in a medium-bore branched pipe under constant pressure at 590° C using a four-material weld model',
#  'CONFERENCES',
#  'Can embedded space system development benefit from agile practices?',
#  'Cascading flowlines and layout modules: Practical strategies for machine duplication in facility layouts',
#  'Challenges and Research Directions in Agent-Oriented Software Engineering',
#  'Challenges and future perspectives for the life cycle of manufacturing networks in the mass customisation era',
#  'Challenges and industry practices for managing software variability in small and medium sized enterprises',
#  'Challenges and practices in aligning requirements with verification and validation: a case study of six companies',
#  'Classification and trend analysis of UML books (1997–2009)',
#  'Co-ordination Functions in a SME Network',
#  'Coherent Models of Processes and Human Systems',
#  'Communication and Creative Thinking in Agile Software Development',
#  'Comparing Business Intelligence and Big Data Skills',
#  'Comparison of CMM Level 2 and eXtreme Programming',
#  'Component prioritisation for strategic purchasing and the case study of a South Korean elevator manufacturer',
#  'Computer-aided design of experiments: an enabler of agile manufacturing',
#  'Constant Refactoring After Programming (If It Ain’t Broke, Fix It Anyway)',
#  'Contracts and Scenarios in the Software Development Process',
#  'Critical Success Factors to Improve the Game Development Process from a Developer’s Perspective',
#  'Critical analysis of vendor lock-in and its impact on cloud computing migration: a business perspective',
#  'Customer Relationship Management',
#  'Decision making using a fuzzy induced linguistic ordered weighted averaging approach for evaluating risk in a supply chain',
#  'Decision-aiding tools in innovative product development contexts',
#  'Defining a Scope for COTS Selection Methods',
#  'Deploy',
#  'Der Arbeitsmarkt für IT-Fachleute in Deutschland',
#  'Design of activities in shop floor management: A holistic approach to organisation at operational business levels in BPR projects',
#  'Design science in action: developing a modeling technique for eliciting requirements on business process management (BPM) tools',
#  'Design with ArgoUML',
#  'Designing Collaborative Systems to Support Reactive Problem-Solving in Manufacturing',
#  'Designing Project Management for Global Software Development',
#  'Designing a supply network artifact for data, process, and people integration',
#  'Designing service systems by bridging the “front stage” and “back stage”',
#  'Detecting Conflicts and Inconsistencies in Web Application Requirements',
#  'Developing an ISDM Adoption Decision Model Using Delphi and AHP',
#  'Development and Build System with Ant',
#  'Development of an intelligent agent-based AGV controller for a flexible manufacturing system',
#  'Development of framework for sustainable Lean implementation: an ISM approach',
#  'Development of real-time PCR method for the detection and the quantification of a new endogenous reference gene in sugar beet “Beta vulgaris L.”: GMO application',
#  'Distributed Demand Flow Customization',
#  'Do Systematic Literature Reviews Outperform Informal Literature Reviews in the Software Engineering Domain? An Initial Case Study',
#  'Domains as a Prerequisite for Requirements and Software Domain Perspectives and Facets, Requirements Aspects and Software Views',
#  'E',
#  'ECR 2014, Part B',
#  'ECR 2015 Book of Abstracts - B - Scientific Sessions and Late-Breaking Clinical Trials',
#  'ESMRMB 2008 Congress, Valencia, Spain, 2–4 October: EPOSGäó Posters / Info-RESO',
#  'ESMRMB 2016, 33rd Annual Scientific Meeting, Vienna, AT, September 29 – October 1: Abstracts, Saturday',
#  'Electrochemistry of CPs',
#  'Empirical evidence in global software engineering: a systematic review',
#  'Enhancing the OPEN Process Framework with service-oriented method fragments',
#  'Enterprise Integration in the User Industries — Needs and Current Solutions',
#  'Enterprise Modelling',
#  'Evaluating Petroleum Supply Chain Performance: Overcoming Shortcomings of Balanced Scorecard',
#  'Evaluating the impact of an agile transformation: a longitudinal case study in a distributed context',
#  'Evaluation of the Reference Model',
#  'Evolutionistic or revolutionary paths? A PACS maturity model for strategic situational planning',
#  'Experience Based Energy Efficient Reactive Routing Protocol (EXERP) for Mobile Ad-Hoc Networks',
#  'Experimental Development of a Prototype for Mobile Environmental Information Systems (MEIS)',
#  'Exploring the costs of technical debt management – a case study',
#  'Exploring the properties of MSC documents by translating them into Petri nets',
#  'Extended value network modelling and simulation for mass customization implementation',
#  'Extreme Programming in a Research Environment',
#  'F',
#  'Final Program: 59th ASMS Conference on Mass Spectrometry and Allied Topics, June 5-9, 2011, Denver, Colorado',
#  'Flexibility of System of Systems',
#  'Fostering effective inter-team knowledge sharing in agile software development',
#  'From Reengineering to Continuous Process Adaptation',
#  'From offshore outsourcing to insourcing and partnerships: four failed outsourcing attempts',
#  'From project-oriented to service-oriented software development: an industrial experience guided by a service reference model',
#  'From testing to anti-product development',
#  'Fuzzy Group Decision-Making in the Measurement of Ecotourism Sustainability Potential',
#  'GUITAR: an innovative tool for automated testing of GUI-driven software',
#  'Game development software engineering process life cycle: a systematic review',
#  'GenUTest: a unit test and mock aspect generation tool',
#  'Genesys: service-oriented construction of property conform code generators',
#  'Governance of global supply chains vulnerability by business-based interorganizational information platform',
#  'Guidelines for conducting and reporting case study research in software engineering',
#  'Guiding the selection of service-oriented software engineering methodologies',
#  'H',
#  'Historical Context',
#  'How to Get the Most out of Extreme Programming/Agile Methods',
#  'How to create an innovation accelerator',
#  'Human-centred appraoches to control and information technology: European experiences',
#  'Hunting for Aardvarks: Can Software Security Be Measured?',
#  'I',
#  'IT at the Shop Floor — Criteria-based Methodologies for Human-Machine Task Allocation',
#  'Identifying and Modelling Complex Workflow Requirements in Web Applications',
#  'Identifying the cause and effect factors of agile NPD process with fuzzy DEMATEL method: the case of Iranian companies',
#  'Implementing Lean into a Servicing Environment',
#  'In the news',
#  'In-Time Role-Specific Notification as Formal Means to Balance Agile Practices in Global Software Development Settings',
#  'Incorporating behavioral trust theory into system development for ubiquitous applications',
#  'Influences on regression testing strategies in agile software development environments',
#  'Information Technology and Supply Chain Management',
#  'Information infrastructure services for small and medium size manufacturers: The MI2CI project',
#  'Information-Integrated Enterprises',
#  'Innovation Management Needs an Interoperable Requirements Management',
#  'Inside the adaptive enterprise: an information technology capabilities perspective on business process agility',
#  'Integrated Image Data and Medical Record Management for Rare Disease Registries. A General Framework and its Instantiation to the German Calciphylaxis Registry',
#  'Integrated fuzzy AHP and fuzzy VIKOR model for supplier selection in an agile and modular virtual enterprise',
#  'Integrating Fuzzy Kano and Fuzzy TOPSIS for Classification of Functional Requirements in National Standardization System',
#  'Integrating Graph Rewriting and Standard Software Tools',
#  'Integrating marketing and information services functions: a complementarity and competence perspective',
#  'Integration and Generification—Agile Software Development in the Healthcare Market',
#  'Intelligent distributed production control',
#  'Interflow systems for manufacturing: concepts and a construction',
#  'Internet of connected ServGoods: Considerations, consequences and concerns',
#  'Introducing Object Validation and Navigation in Software Process to Improve Software Quality',
#  'Introducing UML: Object-Oriented Analysis and Design',
#  'Introduction to Petri Nets in Flexible and Agile Automation',
#  'Introductory overview',
#  'Investigating probabilistic sampling approaches for large-scale surveys in software engineering',
#  'Investigating the effects of personality traits on pair programming in a higher education setting through a family of experiments',
#  'Investigating the extreme programming system–An empirical study',
#  'Ionic Liquids',
#  'Issues on the anthropocentric production systems',
#  'JWalk: a tool for lazy, systematic testing of java classes by design introspection and user interaction',
#  'Keiran J. Dunne and Elena S. Dunne (eds.): Translation and localization project management: the art of the possible',
#  'Keyboards and keying An annotated bibliography of the literature from 1878 to 1999',
#  'Knowledge Management Support for Distributed Agile Software Processes',
#  'L',
#  'LODPRO: learning objects development process',
#  'Logistics and Supply Chain Management for Mass Customization',
#  'M',
#  'MIDAS/BD: A Methodological Framework for Web Database Design',
#  'Main benefits obtained from a successful JIT implementation',
#  'Major motivations for extract method refactorings: analysis based on interviews and change histories',
#  'Making a Method Work for a Project Situation in the Context of CMM',
#  'Managing Evolving Requirements Using eXtreme Programming',
#  'Manufacturing supply chain design and evaluation',
#  'Mapping the Information System Development Process',
#  'Marketing automation systems integration: The art and engineering to make it all work seamlessly',
#  'Mathematical Programming for Earth Observation Satellite Mission Planning',
#  'Measuring the Intangible Aspects of the Manufacturing Strategy – A Case Study from the Automotive Industry',
#  'Meeting Organisational Needs and Quality Assurance through Balancing Agile and Formal Usability Testing Results',
#  'Message choreography modeling',
#  'Metadata-driven interactive web video assembly',
#  'Methodologies to evolve formal specifications through refinement and retrenchment in an analysis–revision cycle',
#  'Midland: a service-oriented cluster computing infrastructure',
#  'Model Based Development of Hybrid Systems: Specification, Simulation, Test Case Generation',
#  'Model-Driven Prototyping for Corporate Software Specification',
#  'Model-based engineering for change-tolerant systems',
#  'Modeling customized product configuration in large assembly manufacturing with supply-chain considerations',
#  'Models, Systems and Reality: Knowledge Generation and Strategies for Systems Design',
#  'Motivation and Outlook',
#  'Multi-agent systems with reinforcement hierarchical neuro-fuzzy models',
#  'Multi-objective ant colony optimization for requirements selection',
#  'New Collaborative Organizations and their Research Needs',
#  'New Machine Tools and Systems',
#  'Object-Relational Mapping',
#  'On guiding the augmentation of an automated test suite via mutation analysis',
#  'On integration and adaptation in complex service systems',
#  'On shared understanding in software engineering: an essay',
#  'On the Impact of Mixing Responsibilities Between Devs and Ops',
#  'On the dataset shift problem in software engineering prediction models',
#  'On the possibilities of (pseudo-) software cloning from external interactions',
#  'Open lean electricity supply communities',
#  'Operational definition and automated inference of\xa0test-driven development with Zorro',
#  'Organizing User Interface Patterns for e-Government Applications',
#  'Overview of sustainable biomass supply chain: from concept to modelling',
#  'P',
#  'Pause, Reflect and Act, the Pursuit of Continuous Transformation',
#  'Philips experiences in global distributed software development',
#  'Planning and Scheduling based on Petri Nets',
#  'Planning and realization of an innovative airline catering production plant: industrial case study',
#  'Planning of manufacturing networks using an intelligent probabilistic approach for mass customised products',
#  'Planning, Training and Learning in Supervision of Flexible Assembly Systems',
#  'Policy-Driven Middleware for Self-adaptation of Web Services Compositions',
#  'Poster Presentations',
#  'Posters',
#  'Pragmatic Software Innovation',
#  'Predicting a model for agile NPD process with fuzzy cognitive map: the case of Iranian manufacturing enterprises',
#  'Preliminaries: 00 and Design Patterns 101',
#  'Principles and application of LIMS in mouse clinics',
#  'Privatization, Postprivatization, and Structural Problems',
#  'Process Patterns for Agile Methodologies',
#  'Professional Ethics of Software Engineers: An Ethical Framework',
#  'Project management: Recent developments and research opportunities',
#  'Prototype system for pursuing firm’s core capability',
#  'Pull control for job shop: holonic manufacturing system approach using multicriteria decision-making',
#  'Quality Assurance in Scrum Applied to Safety  Critical Software',
#  'Quality and the Service Level Agreement',
#  'R',
#  'Rapid and cost-effective manufacturing of high-integrity aerospace components',
#  'Rapid one-of-a-kind product development',
#  'Rationality, Culture and Politics of Production',
#  'Reactive Scheduling in Real Time Production Control',
#  'Real-Time Path Planning Algorithm for Autonomous Border Patrol: Design, Simulation, and Experimentation',
#  'Rebalancing Your Organization’s Agility and Discipline',
#  'Recent advances on key technologies for innovative manufacturing',
#  'Refactoring OCL annotated UML class diagrams',
#  'Reference Model for Operation and Reconfiguration of a Network for Subway Construction',
#  'Reference Models of Fraunhofer DZ-SIMPROLOG',
#  'Reliability analysis on civil engineering project based on integrated adaptive simulation annealing and gray correlation method',
#  'Requirements Engineering and Process Modelling in Software Quality Management— Towards a Generic Process Metamodel',
#  'Research Joint Ventures: Conceptual Foundations Practical Implications',
#  'Research on initiative scheduling mode for a physical internet-based manufacturing system',
#  'Role of Supply Chain Management in Context of Total Quality Management in Flexible Systems: A State-of the-Art Literature Review',
#  'Roles in Innovative Software Teams: A Design Experiment',
#  'S',
#  'Scrum adoption and architectural extensions in developing new service applications of large financial IT systems',
#  'Security Engineering and eXtreme Programming: An Impossible Marriage?',
#  'Sensors',
#  'Services Discovery as a Mean to Enhance Software Resources Sharing in Collaborative Networks',
#  'Shop Controllers-Managers for Intelligent Manufacturing',
#  'Simulation optimization',
#  'Situational Method Quality',
#  'Social CRM as a business strategy',
#  'Social debt in software engineering: insights from industry',
#  'Society of general internal medicine 22nd annual meeting San Francisco, California April 29–May 1, 1999 abstracts',
#  'SoftCoDeR approach: promoting Software Engineering Academia-Industry partnership using CMD, DSR and ESE',
#  'Software Process and Product Improvement: A Historical Perspective',
#  'Software SMEs’ unofficial readiness for CMMI®-based software process improvement',
#  'Software assurance practices for mobile applications',
#  'Software process improvement in small and medium software enterprises: a systematic review',
#  'Solar Weather Event Modelling and\xa0Prediction',
#  'State-of-the-Art and Trends of Computer-Aided Innovation Tools',
#  'Step 5: Repeat to Design Your Components',
#  'Strategy and The Posts',
#  'Strategy selection for sustainable manufacturing with integrated AHP-VIKOR method under interval-valued fuzzy environment',
#  'Suitability of FIT User Acceptance Tests for Specifying Functional Requirements: Developer Perspective',
#  'Supervisory Control Principles for Dynamic Operations Management of Manufacturing Shop Floors',
#  'Supplier Relationship Management',
#  'Supply Chain Flexibility: A Frame Work of Research Dimensions',
#  'Supply Chain Inventory Management',
#  'Supply Chain Management',
#  'Supporting Engineering of Information Systems in Emergent Organizations',
#  'Supporting the Creation of Virtual Enterprises Using Mobile Agents',
#  "Symposium on Harrison's “Lean and Mean”: What are the questions?",
#  'Systematic review of web application security development model',
#  'Systolic Adaptive Beamforming',
#  'T',
#  'Tables with More Structure',
#  'Task-driven manufacturing cloud service proactive discovery and optimal configuration method',
#  'Teacher development with mobiles: Comparative critical factors',
#  'Technical Management: Who and What We Are',
#  'Test',
#  'Testing Software Requirements with Z and Statecharts Applied to an Embedded Control Systemt0t1',
#  'Testing in the Wild: The Social and Organisational Dimensions of Real World Practice',
#  'The 2003 Information Management Project Awards',
#  'The CMS high level trigger',
#  'The Engagement Perspective',
#  'The Impact of an Agile Methodology on the Well Being of Development Teams',
#  'The Link to the ‘Real World’: Information, Knowledge and Experience for Decision Making',
#  'The Role of Gender in Business Process Management Competence Supply',
#  'The Work Force and Information Technology',
#  'The effect of experience on the test-driven development process',
#  'The effect of moving from a plan-driven to an incremental software development approach with agile practices',
#  'The evolution of agile software development in Brazil',
#  'The future trend on system-wide modelling in supply chain studies',
#  'The impact of big data on world-class sustainable manufacturing',
#  'The kanban approach, between agility and leanness: a systematic review',
#  'The network of faults: a complex network approach to prioritize test cases for regression testing',
#  'The relationship between competencies learned in Manufacturing Engineering programs and competencies represented in the CASA/SME Enterprise Wheel Model',
#  'The role of Benchmarking in the Management of Change process Some reflections from the TIME GUIDE project',
#  'The user and quality',
#  'Thirty-criteria-based agility assessment: a case study in an Indian pump manufacturing organisation',
#  'Threshold quality parameters in hybrid higher education',
#  'Time indeterminacy and spatio-temporal building transformations: an approach for architectural heritage understanding',
#  'Time-Based Competition in Multistage Manufacturing: Stream-of-Variation Analysis (SOVA) Methodology—Review',
#  'Tool-assisted unit-test generation and selection based on operational abstractions',
#  'Tools and Methods for Risk Management in Multi-Site Engineering Projects',
#  'Toward a Conceptual Framework of Agile Methods',
#  'Towards Automating Source-Consistent UML Refactorings',
#  'Towards a CMMI-Compliant Goal-Oriented Software Process through Model-Driven Development',
#  'Towards a Capability-Based Decision Support System for a Manufacturing Shop',
#  'Towards a Philosophy of Software Development: 40 Years after the Birth of Software Engineering',
#  'Towards a Unified Definition of Open Source Quality',
#  'Towards a reference architecture for fuel-based carbon management systems in the logistics industry',
#  'Towards an integrated measurement of IS project performance: The project performance scorecard',
#  'Towards lean service bus architecture for industrial integration infrastructure and pull manufacturing strategies',
#  'Towards optimal software engineering: learning from agile practice',
#  'Towards understanding the relationship between team climate and software quality—a quasi-experimental study',
#  'Transformation of the EFQM approach from business towards operations excellence',
#  'Transportation',
#  'Two-stage flow-shop scheduling problem with non-identical second stage assembly machines',
#  'UML Models of Development Processes',
#  'Understanding the Influence of User Participation and Involvement on System Success – a Systematic Mapping Study',
#  'Universal smoothing factor selection in density estimation: theory and practice',
#  'University of Vienna’s U:SPACE Turning Around a Failed Large Project by Becoming Agile',
#  'User Stories and Acceptance Tests',
#  'Users’ involvement may help respect social and ethical values and improve software quality',
#  'Using Developer Activity Data to Enhance Awareness during Collaborative Software Development',
#  'Using Storyotypes to Split Bloated XP Stories',
#  'Using a Reference Application with Design Patterns to Produce Industrial Software',
#  'Using analytic network process to analyze problems for implementing turn-key construction projects in Taiwan',
#  'Using grounded theory to study the experience of software development',
#  'VCS: value chains simulator, a tool for value analysis of manufacturing enterprise processes (a value-based decision support tool)',
#  'Value Stream Mapping: a study about the problems and challenges found in the literature from the past 15\xa0years about application of Lean tools',
#  'Variations over Test Suite Reduction',
#  'Verification, Validation, and Accreditation of Simulation Models',
#  'Views and Experiences of Configuration Management',
#  'Virtual Enterprise Modeling and Support Infrastructures: Applying Multi-agent System Approaches',
#  'Waste identification and elimination in information technology organizations',
#  'Web-based distributed manufacturing control systems',
#  'Web-based systems design: a study of contemporary practices and an explanatory framework based on “method-in-action”',
#  'What Counts as Software Process? Negotiating the Boundary of Software Work Through Artifacts and Conversation',
#  'What can agents do in industry, and why? An overview of industrially-oriented R&D at CEC',
#  'What is Business Process Management: A Two Stage Literature Review of an Emerging Field',
#  'When XP Met Outsourcing',
#  'Where are the World’s Top 100 I.T. Firms and Why?',
#  'Workshop videos for requirements communication',
#  'Workshops and Tutorials at the UML 2001 Conference',
#  'World Directory of Robotics Research and Development Activities',
#  'e-Infrastructures for e-Science: A Global View',
#  'iSIM: An integrated design method for commercializing service innovation'}

# %%
df["Item Title"]
# Out:
# 0      The evolution of agile software development in...
# 1      Security Engineering and eXtreme Programming: ...
# 2      Agile methods for embedded systems development...
# 3                Agile Entwicklung Web-basierter Systeme
# 4                             Situational Method Quality
# 5      The kanban approach, between agility and leann...
# 6      Achieving CMMI Level 2 with Enhanced Extreme P...
# 7      How to Get the Most out of Extreme Programming...
# 8            Assessing agile methods: An empirical study
# 9               Process Patterns for Agile Methodologies
# 10     Investigating the extreme programming system–A...
# 11     Blending Scrum practices and CMMI project mana...
# 12     Agility Measurements Mismatch: A Validation St...
# 13     A knowledge-based framework for extracting com...
# 14     Towards optimal software engineering: learning...
# 15     Managing Evolving Requirements Using eXtreme P...
# 16         Extreme Programming in a Research Environment
# 17     The effect of moving from a plan-driven to an ...
# 18     A dependency taxonomy for agile software devel...
# 19             Abstracts of Documents in This Supplement
# 20     Comparison of CMM Level 2 and eXtreme Programming
# 21     Agility in Information Systems Development: A ...
# 22     Quality Assurance in Scrum Applied to Safety  ...
# 23     Communication and Creative Thinking in Agile S...
# 24     Scrum adoption and architectural extensions in...
# 25     Agile Principles and Open Source Software Deve...
# 26                                          An Agile CMM
# 27        Toward a Conceptual Framework of Agile Methods
# 28     Investigating probabilistic sampling approache...
# 29     Fostering effective inter-team knowledge shari...
#                              ...
# 414    An Overview of Manufacturing And Supply System...
# 415    A Digital Transparent Satellite Payload Concep...
# 416    On guiding the augmentation of an automated te...
# 417                                                    F
# 418    Development of real-time PCR method for the de...
# 419    Modeling customized product configuration in l...
# 420    Abstracts der 6. Jahrestagung Deutsche Gesells...
# 421    Supporting the Creation of Virtual Enterprises...
# 422    Reliability analysis on civil engineering proj...
# 423    Teacher development with mobiles: Comparative ...
# 424    Evolutionistic or revolutionary paths? A PACS ...
# 425    An integrated modeling method for assessment o...
# 426    Integrating marketing and information services...
# 427                              Electrochemistry of CPs
# 428    A decision support system for analysis of effe...
# 429    A Web-Based System for Interface Management of...
# 430    Development of an intelligent agent-based AGV ...
# 431    Prototype system for pursuing firm’s core capa...
# 432    The Link to the ‘Real World’: Information, Kno...
# 433    Governance of global supply chains vulnerabili...
# 434    A genetic algorithm for solving no-wait flexib...
# 435                           Tables with More Structure
# 436    Threshold quality parameters in hybrid higher ...
# 437    A domain-specific decision support system for ...
# 438    Real-Time Path Planning Algorithm for Autonomo...
# 439     Der Arbeitsmarkt für IT-Fachleute in Deutschland
# 440    An Integrated Framework for Service Quality, C...
# 441    Experience Based Energy Efficient Reactive Rou...
# 442    Time indeterminacy and spatio-temporal buildin...
# 443    Mathematical Programming for Earth Observation...
# Name: Item Title, dtype: object

# %%
# %%time
lista1 = [
    tuple(data.tolist())
    for index, data in df.iterrows()
]
print (lista1)

# %%
# %%time
lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(data.tolist()))
print (lista1)

# %%
import bibtexparser
with open("Backward_P4.txt", "r") as f:
    citations = bibtexparser.load(f)
    
def get_title(x):
    if 'title' in x:
        return x['title']
    return x['journal']
{get_title(x) for x in citations.entries}
