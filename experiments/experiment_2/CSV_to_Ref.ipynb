# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Erica/Downloads/SearchResults263Result.csv")

#df = pd.read_csv("C:/Users/Erica/Documents/Mestrado_LeoMurtaEricaMourao/Mestrado_Experimentos/Experimento_03/SearchResultsSpringer.csv")

# %%
df
# Out:
#                                             Item Title  \
# 0              Domain I Continued: Agile Methodologies
# 1                                         Introduction
# 2                           Agile Software Development
# 3                                              Develop
# 4                        Glossar zu Agilität in der IT
# 5           The Roots of Agile: History and Background
# 6                         Lean and Agile in a Nutshell
# 7             Introduction to Scrum and Agile Concepts
# 8                                        Agile methods
# 9               Domain I: Agile Principles and Mindset
# 10                                Foundations of Agile
# 11     Zurückeroberung der Zukunft — Chancen agiler IT
# 12                      Applying Agile Risk Management
# 13                    Domain II: Value-Driven Delivery
# 14                                 eXtreme Programming
# 15   Definition of Ready: An Experience Report from...
# ...

# %%
import re
for i, row in df.iterrows():
    print(f"[{i}]")
    print(re.sub(r"([a-z])([A-Z])", r"\1 and \2", row.Authors))
    print(row["Item Title"])
    print(row["Publication Title"])
    print(f"doi={row['Item DOI']}")
    print(row["Publication Year"])
    print()
# Out:
# [0]
# Sumanta Boral
# Domain I Continued: Agile Methodologies
# Ace the PMI-ACP® exam
# doi=10.1007/978-1-4842-2526-4_2
# 2016
#
# [1]
# Alan Moran
# Introduction
# Managing Agile
# doi=10.1007/978-3-319-16262-1_1
# 2015
#
# [2]
# Alan Moran
# Agile Software Development
# Agile Risk Management
# doi=10.1007/978-3-319-05008-9_1
# 2014
#
# [3]
# Tathagat Varma
# Develop
# Agile Product Development
# doi=10.1007/978-1-4842-1067-3_6
# 2015
#
# [4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a8182dbee5a7> in <module>()
#       2 for i, row in df.iterrows():
#       3     print(f"[{i}]")
# ----> 4     print(re.sub(r"([a-z])([A-Z])", r"\1 and \2", row.Authors))
#       5     print(row["Item Title"])
#       6     print(row["Publication Title"])
#
# C:\ProgramData\Anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
# ...

# %%
import re

# %%
re.sub?

# %%
import re
for i, row in df.iterrows():
    print(f"[{i}]")
    print(
        if row.Authors == "NaN", "Author"
        else re.sub(r"([a-z])([A-Z])", r"\1 and \2", row.Authors))
    print(row["Item Title"])
    print(row["Publication Title"])
    print(f"doi={row['Item DOI']}")
    print(row["Publication Year"])
    print()
# Out:
#   File "<ipython-input-5-26d2ab0e0682>", line 5
#     if (row.Authors == 'NaN', 'Author')
#      ^
# SyntaxError: invalid syntax
