# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import database
import xlrd
from hover_graph import HoverGraph as Graph
from snowballing.operations import reload, compare_str, load_work_map_all_years
from snowballing.dbmanager import set_attribute
reload()
import pandas as pd

import math
def isnan(num):
    if isinstance(num, str):
        return False
    return math.isnan(num)
ratio = 0.9
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
#pd.set_option('display.max_colwidth', -1)
todo = []

# %%
#SCOPUS

#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "scopus",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemScopus",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#EL COMPENDEX

#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "ElCompendex",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemElCompendex",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#SPRINGER


#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "Springer",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "SemSpringer",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))

# %%
#Outro exemplo, mas sem hash e sem lower case

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(data.tolist())
print (lista1)
    
df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(data2.tolist())
    
print (lista2)

def intersection(lista1, lista2):
    lista3 = [value for value in lista1 if value in lista2]
    return lista3

print(intersection(lista1, lista2))

# %%
# Outro exemplo, mas sem o import.

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(data.tolist()))
print (lista1)

df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(tuple(data2.tolist()))
    
print (lista2)

def intersection(lista1, lista2):
    temp = set(lista2)
    lista3 = [value for value in lista1 if value in temp]
    return lista3

print(intersection(lista1, lista2))

# %%
#CSV E XLSX

#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo csv
df = pd.read_csv("scopus19072018.csv")

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba do XLSX
df2 = pd.read_excel("SemScopusExp3.xlsx")

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print ("\n Lista dos duplicados: \n")
print(intersection(lista1, lista2))
# Out:
# [('standards-based metamodel for the management of goals, risks and evidences in critical systems development', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84965066556&doi=10.1016%2fj.csi.2016.04.004&partnerid=40&md5=365ea63ee0f467e5df8d19c568b08661'), ('alm tool data usage in software process metamodeling', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85020757592&doi=10.1109%2fseaa.2016.37&partnerid=40&md5=6bcc0286848b0302aeb616d24b6c474f'), ('risk management applied to software development projects in incubated technology-based companies: literature review, classification, and analysis', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85007369028&doi=10.1590%2f0104-530x472-15&partnerid=40&md5=89e43e7944164cec47322ed64f7d6d09'), ('industrial information integration—a literature review 2006–2015', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85010280254&doi=10.1016%2fj.jii.2016.04.004&partnerid=40&md5=c81aaf8eb7b924aa8d658c0d4530526c'), ('managing the alignment between business processes and software systems', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84958658482&doi=10.1016%2fj.infsof.2015.12.009&partnerid=40&md5=ca93cbbdd644a50aeb0c0216d4f35a7c'), ('23rd european conference on systems, software and services process improvement, eurospi 2016', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84987968052&partnerid=40&md5=a3028383cbdbcdbae71c90377eff2808'), ('towards supporting international standard-based software engineering approaches using semantic web technologies: a systematic literature review', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84996957301&doi=10.1007%2f978-3-319-48024-4_14&partnerid=40&md5=4a5d295f8b13fb878d4511026a3fbc1f'), ('software measurement linkage for cmmi implementation', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85007106919&partnerid=40&md5=7f9c976b937a4bcc1f7034e3ba6e9683'), ('a process for creating the elicitation guide of non-functional requirements', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84964734943&doi=10.1007%2f978-3-319-33622-0_27&partnerid=40&md5=ab32c36560a0f8679c43354523cfbd80'), ('software engineering process theory: a multi-method comparison of sensemaking-coevolution-implementation theory and function-behavior-structure theory', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84949533182&doi=10.1016%2fj.infsof.2015.06.010&partnerid=40&md5=f545aa6363dc6b697dddb1b844b095d4'), ('business process maturity assessment: state of the art and key characteristics', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84958260485&doi=10.1109%2fseaa.2015.50&partnerid=40&md5=50674d3611ae7cb05eb82200b1bd33b3'), ('towards an ontology pattern language for harmonizing software process related iso standards', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84955504362&doi=10.1145%2f2695664.2695796&partnerid=40&md5=4f0a7151062ea9513be1238bd75bddac'), ('methodologies for evaluation and improvement of software processes in the context of quality and maturity models: a systematic mapping', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84936132896&partnerid=40&md5=05f39184c82e863f80cb931f777ad80c'), ('a process capability based assessment model for software workforce in emergent software organizations', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84908659446&doi=10.1016%2fj.csi.2014.05.003&partnerid=40&md5=1f25e0ff0cafbdfad353fb727ecb39e4'), ('lean quality improvement model for quality practices in software industry in pakistan', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84973439836&doi=10.1002%2fsmr.1709&partnerid=40&md5=11bc290d024c48039fb47722af093679'), ('implementing information security best practices on software lifecycle processes: the iso/iec 15504 security extension', 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84908268449&doi=10.1016%2fj.cose.2014.09.003&partnerid=40&md5=7ed5c55b4de0d6fd658539028ba08f5c'), ('towards the development of a framework for encouraging the learning ...
# [('a software process ontology and its application',), ('an ontology based infrastructure to support cmmi-based software process assessment',), ('a strategic test process improvement approach using an ontological description for mnd-tmm',), ('managing software process measurement: a metamodel-based approach',), ('applying a framework for the improvement of software process maturity',), ('defining software process model constraints with rules using owl and swrl',), ('an ontology for the management of software maintenance projects',), ('a software process ontology as a common vocabulary about software processes',), ('harnessing software development contexts to inform software process selection decisions',), ('framework for usage of multiple software process models',), ('project assets ontology (pao) to support gap analysis for organization process improvement based on cmmi v. 1.2',), ('building process definition with ontology background',), ('an xmi-based repository for software process meta-modeling',), ('a framework and tool for modelling and assessing software development processes',), ('usage of multiple process assessment models',), ('quality in development process for software factories according to iso 15504',), ('ontology based bayesian software process improvenent',), ('automated software engineering process assessment: supporting diverse models using an ontology',), ('research directions in verification & validation process improvement',), ('a process framework for semantics-aware tourism information systems',), ('software process improvement in europe: potential of the new v‐modell xt and research issues',), ('ontologies for software project management: a review',), ('a partial formalization of the cmmi-dev—a capability maturity model for development',), ('semantic based approach supporting cmmi gap analysis process.',), ('a cmmi ontology for an ontology-based software process assessment tool',), ('ontology-based architecture to support software process improvement',), ('proposing an iso/iec 15504-2 compliant method for process capability/maturity models customization',), ('trends in harmonization of multiple reference models',), ('a well-founded software measurement ontology.',), ('requirements change management process models: an evaluation',), ('a process-ontological model for software engineering.',), ('defining spem 2 process constraints with semantic rules using swrl',), ('enhancing the conceptual framework capability for a measurement and evaluation strategy',), ('maturity assessment and process improvement for information security management in small and medium enterprises',), ('know how and know what for software processes',), ('spem ontology as the semantic notation for method and process definition in the context of swebok',), ('a framework for modelling software development processes',), ('software maintenance maturity model (smmm): the software maintenance process model',), ('the sprint-smes approach for software process improvement in small-medium sized software development enterprises',), ('a process meta-model in a gradual software process implementation environment',), ('a strategy for preparing software organizations for statistical process control',), ('a methodology for establishing multi-model environments in order to improve organizational software processes',), ('towards automated process assessment in software engineering',), ('towards methodological support for the engineering of process reference models for product software',), ('towards an ontology pattern language for harmonizing software process related iso standards',), ('modelling software development processes and standards',), ('ontology driven benchmarking on itil to achieve six sigma',), ('automated support of software quality improvement',), ('an iso/iec 15504 based software process assessment in small software companies',), ('software process and product measurement: international conferences iwsm 2008, metrikon 2008, and mensura  ...
#
#  Lista dos duplicados:
#
# []

# %%
#CSV E XLSX

#Somente essa célula precisa ser executada
import os, sys
import pandas as pd

df = pd.read_csv("scopus19072018.csv")
lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(x.lower() for x in data.tolist()))
    
lista3=set(df.iloc[:,0].tolist())

df2 = pd.read_excel("SemScopusExp3.xlsx")

lista2 = set(df2.iloc[:,0].tolist())

#lista3 = lista1 & lista2
#df3 = lista3
#df3
# Out:
# {'Tool-based requirement traceability between requirement and design artifacts', 'An approach for designing of enterprise it landscapes to perform quantitave information security risk assessment', 'Establishing and maintaining traceability between large aerospace process standards', 'EGIF4M: Egovernment interoperability framework for Mozambique', 'Bringing contextual dimensions into the improvement of information system development practices', 'Semantic based approach supporting CMMI gap analysis process', 'Defining SPEM 2 process constraints with semantic rules using SWRL', 'Proposing an ISO/IEC 15504-2 compliant method for process capability/maturity models customization', 'Defining the process for making software system modernization decisions', 'Situational method engineering: State-of-the-art review', 'Compliance management with measurement frameworks', 'Medical device software traceability', 'A software process ontology as a common vocabulary about software processes', 'Homogenization of models in improved environments multiframe processes [Homogenización de marcos en ambientes de mejora de procesos multimarco]', 'A systematic literature review on the industrial use of software process simulation', 'Comparing SPiCE for Space (S4S) and CMMI-DEV: Identifying Sources of Risk from Improvement Models', 'Knowledge management in process improvement and best practices sharing', 'Methodologies for evaluation and improvement of software processes in the context of quality and maturity models: A systematic mapping', 'The feasibility of using UML to compare the impact of different brands of computer system on the clinical consultation', 'An approach for designing of enterprise IT landscapes to perform quantitave information security risk assessment', 'Software Maintenance Management: Evaluation and Continuous Improvement', 'Semantic process management environment', 'Ontology based Bayesian software process improvenent', 'An XMI-based repository for software process meta-modeling', 'Efficient adoption and assessment of multiple process improvement reference models', 'Situational method engineering', 'Towards the development of a framework for encouraging the learning of SPICE model by using knowledge graphs', 'An ISO/IEC 15504 based software process assessment in small software companies', 'Managing the alignment between business processes and software systems', 'Evaluating the assessment method of the software maintenance maturity model', 'ISO/IEC 15504, a basis for generally accepted sound process models in financial institutions a case study about venture capital fund management', 'Using ontologies in software engineering and technology', 'Engineering and reengineering of technology enhanced learning scenarios using context awareness processes', 'Software Maintenance Maturity Model (SMmm): The software maintenance process model', 'Taba workstation: Supporting software process improvement initiatives based on software standards and maturity models', 'Corrective maintenance maturity model: Problem management', 'A method to define an object oriented software process architecture', 'An ontology for the management of software maintenance projects', 'Lean quality improvement model for quality practices in software industry in Pakistan', 'Risk management applied to Software development projects in incubated technology-based companies: Literature review, classification, and analysis', 'A process capability based assessment model for software workforce in emergent software organizations', 'The lean gap: A review of lean approaches to large-scale software systems development', 'The LEGO strategy: Guidelines for a profitable deployment', 'Using a reference domain ontology for developing a software measurement strategy for high maturity organizations', 'Implementing information security best practices on software lifecycle processes: The ISO/IEC 15504 Security Extension', 'Customizing the representation capabilities of process models: Underst ...

# %%
df = pd.read_csv("scopus19072018.csv")

set(df.iloc[:,0].tolist())
# Out:
# {'23rd European Conference on Systems, Software and Services Process Improvement, EuroSPI 2016',
#  'A Hybrid Method for E-process Selection',
#  'A method to define an object oriented software process architecture',
#  'A methodology for establishing multi-model environments in order to improve organizational software processes',
#  'A process capability based assessment model for software workforce in emergent software organizations',
#  'A process for creating the elicitation guide of non-functional requirements',
#  'A process framework for semantics-aware tourism information systems',
#  'A process reference model for managing living labs for ICT innovation: A proposal based on ISO/IEC 15504',
#  'A process-ontological model for software engineering',
#  'A software process ontology as a common vocabulary about software processes',
#  'A strategic test process improvement approach using an ontological description for MND-TMM',
#  'A strategy for preparing software organizations for statistical process control',
#  'A systematic literature review on the industrial use of software process simulation',
#  'A taxonomy for requirements engineering and software test alignment',
#  'A well-founded software measurement ontology',
#  'ALM Tool Data Usage in Software Process Metamodeling',
#  'Action Research Can Swing the Balance in Experimental Software Engineering',
#  'An ISO/IEC 15504 based software process assessment in small software companies',
#  'An XMI-based repository for software process meta-modeling',
#  'An approach for designing of enterprise IT landscapes to perform quantitave information security risk assessment',
#  'An approach for designing of enterprise it landscapes to perform quantitave information security risk assessment',
#  'An approach to capture authorisation requirements in business processes',
#  'An approach to modelling software evolution processes',
#  'An ontology based infrastructure to support CMMI-based software process assessment',
#  'An ontology for ISO software engineering standards: 1) Creating the infrastructure',
#  'An ontology for software development methodologies and endeavours',
#  'An ontology for software measurement',
#  'An ontology for the management of software maintenance projects',
#  'Applying a framework for the improvement of software process maturity',
#  'Asynchronous merging of software ontologies: An experience',
#  'Bringing contextual dimensions into the improvement of information system development practices',
#  'Business Process Maturity Assessment: State of the Art and Key Characteristics',
#  'Capability maturity for knowledge management',
#  'Comparing SPiCE for Space (S4S) and CMMI-DEV: Identifying Sources of Risk from Improvement Models',
#  'Comparing agility analysis techniques: AgilAC framework versus ad hoc approach',
#  'Compliance management with measurement frameworks',
#  'Corrective maintenance maturity model: Problem management',
#  'Customizing the representation capabilities of process models: Understanding the effects of perceived modeling impediments',
#  'Defining SPEM 2 process constraints with semantic rules using SWRL',
#  'Defining the process for making software system modernization decisions',
#  'EGIF4M: Egovernment interoperability framework for Mozambique',
#  'Efficient adoption and assessment of multiple process improvement reference models',
#  'Engineering and reengineering of technology enhanced learning scenarios using context awareness processes',
#  'Enhancing ISO/IEC 15288 with reuse and product management: An add-on process reference model',
#  'Enhancing the conceptual framework capability for a measurement and evaluation strategy',
#  'Establishing and maintaining traceability between large aerospace process standards',
#  'Evaluating the assessment method of the software maintenance maturity model',
#  'Evaluation and measurement of software process improvement-A systematic literature review',
#  'Evolving process improvement using multi-model enviroments and knowledge management [Evolucionando la mejora de procesos basada en el uso de entornos multimodelo y la gestión del conocimiento]',
#  'Homogenization of models in improved environments multiframe processes [Homogenización de marcos en ambientes de mejora de procesos multimarco]',
#  'IQM3: Information quality management maturity model',
#  'ISO/IEC 15504, a basis for generally accepted sound process models in financial institutions a case study about venture capital fund management',
#  'ITIL in small to medium-sized enterprises software companies: Towards an implementation sequence',
#  'Identifying criteria for multimodel software process improvement solutions-based on a review of current problems and initiatives',
#  'Implementing information security best practices on software lifecycle processes: The ISO/IEC 15504 Security Extension',
#  'Improvement of task management with process models in small and medium software companies',
#  'Industrial information integration—A literature review 2006–2015',
#  'Knowledge management in process improvement and best practices sharing',
#  'Knowledge-oriented software engineering process in a multi-cultural context',
#  'Lean quality improvement model for quality practices in software industry in Pakistan',
#  'MIN-ITs: A framework for integration of IT management standards in mature environments',
#  'Managing the alignment between business processes and software systems',
#  'Mapping of improvement models as a risk reduction strategy: a theoretical comparison for the aerospace industry',
#  'Medical device software traceability',
#  'Methodologies for evaluation and improvement of software processes in the context of quality and maturity models: A systematic mapping',
#  'Ontology based Bayesian software process improvenent',
#  'Ontology based software development good practices selection for adoption in micro-enterprises',
#  'Organizational learning applied to software engineering: A systematic review',
#  'Proposing an ISO/IEC 15504-2 compliant method for process capability/maturity models customization',
#  'Random thoughts on multi-level conceptual modelling',
#  'Requirements change management process models: An evaluation',
#  'Risk management applied to Software development projects in incubated technology-based companies: Literature review, classification, and analysis',
#  'SPEM Ontology as the semantic notation for method and process definition in the context of SWEBOK',
#  'Semantic based approach supporting CMMI gap analysis process',
#  'Semantic process management environment',
#  'Situational method engineering',
#  'Situational method engineering: State-of-the-art review',
#  'Software Maintenance Management: Evaluation and Continuous Improvement',
#  'Software Maintenance Maturity Model (SMmm): The software maintenance process model',
#  'Software engineering process theory: A multi-method comparison of Sensemaking-Coevolution-Implementation Theory and function-behavior-structure theory',
#  'Software measurement linkage for CMMI implementation',
#  'Software or service? That’s the question!',
#  'Software process improvement in small and medium software enterprises: A systematic review',
#  'Software process management assessment towards CMM a systematic approach to optimize internal process improvement',
#  'Software process practices in small software companies in botswana',
#  'Standards-based metamodel for the management of goals, risks and evidences in critical systems development',
#  'Taba workstation: Supporting software process improvement initiatives based on software standards and maturity models',
#  'Techniques for merging views of software processes',
#  'The LEGO strategy: Guidelines for a profitable deployment',
#  'The feasibility of using UML to compare the impact of different brands of computer system on the clinical consultation',
#  'The lean gap: A review of lean approaches to large-scale software systems development',
#  'The making of an OMG standard',
#  'Tool for usage of multiple process assessment models',
#  'Tool-based requirement traceability between requirement and design artifacts',
#  'Towards an ontology pattern language for harmonizing software process related ISO standards',
#  'Towards knowledge management to support decision making for software process development',
#  'Towards methodological support for the engineering of process reference models for product software',
#  'Towards supporting international standard-based software engineering approaches using semantic web technologies: A systematic literature review',
#  'Towards the development of a framework for encouraging the learning of SPICE model by using knowledge graphs',
#  'Towards the process-ontological modelling',
#  'Transforming and tracing reused requirements models to home automation models',
#  'Using Unified Modelling Language (UML) as a process-modelling technique for clinical-research process improvement',
#  'Using a reference domain ontology for developing a software measurement strategy for high maturity organizations',
#  'Using model comparison to maintain model-to-standard compliance',
#  'Using ontologies in software engineering and technology'}

# %%
#CSV E XLSX

#Somente essa célula precisa ser executada
import os, sys
import pandas as pd

df = pd.read_csv("scopus19072018.csv")
    
lista1=set(map(str.lower, df.iloc[:,0].tolist()))

df2 = pd.read_excel("SemScopusExp3.xlsx")

lista2 = set(map(str.lower, df2.iloc[:,0].tolist()))

df3 = lista1 & lista2

len(df3)

#FALTOU O LOWER PARA VERIFICAR!
# Out:
# 73

# %%
df["Title"]

# %%
# %%time
lista1 = [
    tuple(data.tolist())
    for index, data in df.iterrows()
]
print (lista1)

# %%
# %%time
lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(data.tolist()))
print (lista1)

# %%
import bibtexparser
with open("Backward_P4.txt", "r") as f:
    citations = bibtexparser.load(f)
    
def get_title(x):
    if 'title' in x:
        return x['title']
    return x['journal']
{get_title(x) for x in citations.entries}
