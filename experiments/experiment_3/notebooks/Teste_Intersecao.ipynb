# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import database
import xlrd
from hover_graph import HoverGraph as Graph
from snowballing.operations import reload, compare_str, load_work_map_all_years
from snowballing.dbmanager import set_attribute
reload()
import pandas as pd

import math
def isnan(num):
    if isinstance(num, str):
        return False
    return math.isnan(num)
ratio = 0.9
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
pd.set_option('display.max_colwidth', -1)
todo = []

# %%
#Somente essa célula precisa ser executada.
import os, sys
import pandas as pd

# Abertura e leitura do arquivo excel
xls = pd.ExcelFile("povoado.xls")

# Leitura da primeira aba da planilha
df = pd.read_excel(xls, "P1",  header=None)

# Criação de lista 1 com as linhas da primeira aba da planilha
lista1=[]

for row in df.iterrows():
    index, data = row
    #lista1.append(tuple(data.tolist()))
    lista1.append(tuple(x.lower() for x in data.tolist()))

print (lista1)

# Leitura da segunda aba da planilha
df2 = pd.read_excel(xls, "P2",  header=None)

# Criação de lista 2 com as linhas da segunda aba da planilha
lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    #lista2.append(tuple(data2.tolist()))
    lista2.append(tuple(x.lower() for x in data2.tolist()))
    
print (lista2)


# Método que calcula a interseção entre os objetos da lista
def intersection(lista1, lista2):
    return list(set(lista1) & set(lista2))

print(intersection(lista1, lista2))
# Out:
# [('definition of ready: an experience report from teams at cisco',), ('adapting scrum to the italian army: methods and (open) tools',), ('securing scrum for vahti',), ('an agile transition starting with user stories, dod & dor',), ('a systematic review on the use of definition of done on agile software development projects',), ('simulation of kanban-based scheduling for systems of systems: initial results',), ('social contracts, simple rules and self-organization: a perspective on agile development',), ('applying scrum to the army: a case study',), ('systems engineering processes for agile software development',), ('agile hardware and software systems engineering for critical military space applications',), ('aminsep-agile methodology implementation for a new software engineering paradigm definition. a research project proposal',), ('agile and m&s - maximizing the efficiency of your m&s projects',), ('security engineering and extreme programming: an impossible marriage?',), ('datasem: a simulation suite for sose management research',), ('emerging directions in aerospace software v&v',)]
# [('adapting scrum to the italian army: methods and (open) tools',), ('systems engineering processes for agile software development',), ('agile hardware and software systems engineering for critical military space applications',), ('what you always wanted to know about agile methods but did not dare to ask',), ('a fishbowl with piranhas: coalescence, convergence or divergence?',), ('empirical study of agile software development methodologies: a comparative analysis',), ('science of design',), ('introduction to research papers',), ('patterns for agile development practice part 3 (version 4)',), ('letters from the edge of an agile transition',), ('adopting an agile methodology: why it did not work',), ('a knowledge transfer framework for supporting the transition to agile development of web application in the thai telecommunications industry',), ('software architecture and agile software development: a clash of two cultures?',), ('creating an informative workspace',), ('combining systematic reuse with agile development: experience report',), ('survey on agile and lean usage in finnish software industry',), ('scrum for cyber-physical systems: a process proposal',), ('agile methods: moving towards the mainstream of the software industry',), ('agility unlimited?',), ('agile development: overcoming a short-term focus in implementing best practices',), ('better planning via tasking as a team',), ('agile development of secure web applications',), ('empirical investigation of agile software development: cloud perspective',), ('can we do useful industrial software engineering research in the shadow of lean and agile?',), ('programmers are from mars, customers are from venus: a practical guide for customers on xp projects',), ('rdp technique: a practice to customize xp',), ('agile portfolio management at finnish broadcasting company yle',), ('supported approach for agile methods adaptation: an adoption study',), ('devops meets formal modelling in high-criticality complex systems',), ('agile software engineering as creative work',), ('best practices in extreme programming course design',), ('aligning architecture knowledge management with scrum',), ('extending xp practices to support security requirements engineering',), ('a comparison of security assurance support of agile software development methods',), ('designing empirical studies: assessing the effectiveness of agile methods',), ('a new business model of custom software development for agile software development',), ('building lean thinking in a telecom software development organization: strengths and challenges',), ('proceedings on the 1st workshop on agile methods applied to development and certification of safety-critical software',), ('fisa-xp: an agile-based integration of security activities with extreme programming',), ('a literature review of agile practices and their effects in scientific software development',), ('agile development in computer science education: practices and prognosis',), ('teaching requirements engineering: euroweb experience',), ('agile development methods through the eyes of organisational network analysis',), ('lean startup: why large software companies should care',), ('a report on the xp workshop on agile product line engineering',), ('when user experience met agile: a case study',), ('a model for estimating agile project process and schedule acceleration',), ('high-integrity extreme programming',), ('stakeholder theory and agile software development',), ('a cognitive perspective on software development methods: the case of extreme programming',), ('extreme usability: adapting research approaches for agile development',), ('teaching agile: addressing the conflict between project delivery and application of agile methods',), ('games for teaching software development',), ('what agile teams think of agile principles',), ('exploring the impact of situational context: a case study of a software development process for a microservices architecture',), ('a  ...
# [('adapting scrum to the italian army: methods and (open) tools',), ('definition of ready: an experience report from teams at cisco',), ('securing scrum for vahti',), ('social contracts, simple rules and self-organization: a perspective on agile development',), ('applying scrum to the army: a case study',), ('agile hardware and software systems engineering for critical military space applications',), ('systems engineering processes for agile software development',), ('emerging directions in aerospace software v&v',)]

# %%
#Outro exemplo, mas sem hash e sem lower case

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(data.tolist())
print (lista1)
    
df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(data2.tolist())
    
print (lista2)

def intersection(lista1, lista2):
    lista3 = [value for value in lista1 if value in lista2]
    return lista3

print(intersection(lista1, lista2))

# %%
# Outro exemplo, mas sem o import.

xls = pd.ExcelFile("povoado.xls")

df = pd.read_excel(xls, "P1",  header=None)

lista1=[]

for row in df.iterrows():
    index, data = row
    lista1.append(tuple(data.tolist()))
print (lista1)

df2 = pd.read_excel(xls, "P2",  header=None)

lista2=[]

for row2 in df2.iterrows():
    index, data2 = row2
    lista2.append(tuple(data2.tolist()))
    
print (lista2)

def intersection(lista1, lista2):
    temp = set(lista2)
    lista3 = [value for value in lista1 if value in temp]
    return lista3

print(intersection(lista1, lista2))
