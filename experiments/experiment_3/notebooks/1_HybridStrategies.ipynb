# %% [markdown]
# # Investigating Hybrid Strategies for Systematic Literature Review
# **Experiment 3**
#
# **Study**
#
#   On the use of ontologies in software process assessment: a systematic literature review
#
#   Tarhan, Ayça and Giray, Gorkem
#
#   21st International Conference on Evaluation and Assessment in Software Engineering, EASE 2017

# %%
# %matplotlib inline

import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import database
from snowballing.operations import reload, work_by_varname, load_work_map_all_years
from snowballing.strategies import Strategy, State
import custom_strategies
from functools import reduce
from matplotlib_venn import venn2, venn2_circles
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

custom_strategies.LIMIT_YEAR = 2016
reload()
# !pip install matplotlib-venn

SVG = False

# %%
import statistics as s
from collections import Counter, deque
from snowballing.operations import metakey, metakey_title

def busca(*libraries, seed=None, filter_function=None):
    filter_function = filter_function or (lambda x: x.category in ("snowball",))
    if seed is not None:
        iterable = ((1, work_by_varname(x)) for x in seed)
    else:
        iterable = load_work_map_all_years()
    seedset = set()
    visited = set()
    for _, work in iterable:
        for library in libraries:
            if int(getattr(work, library, 0)):
                visited.add(work)
                if filter_function(work):
                    seedset.add(work)
                break
    return seedset, filter_function, visited

def descreve_delta(strategy, state, name):
    target = state.find(name)
    previous_related = reduce(lambda x, y: x | y, (s.related for s in target.previous[0]), set())
    for work in previous_related:
        backward = set(strategy.ref[work]) & target.delta_visited
        if backward:
            print('backward', work.metakey)
            for ref in backward:
                print('-', ref.metakey, 'related' if ref in target.delta_related else '')
        forward = set(strategy.rev_ref[work]) & target.delta_visited
        if forward:
            print('forward', work.metakey)
            for ref in forward:
                print('-', ref.metakey, 'related' if ref in target.delta_related else '')

def separa_backward_forward(state):
    backward = set()
    forward = set()
    stack = [state]
    visited = {id(state)}
    while stack:
        current = stack.pop()
        if current.previous:
            if current.previous[1] == "backward":
                backward |= current.delta_related
            if current.previous[1] == "forward":
                forward |= current.delta_related
                
            antecessors = current.previous[0]
            for previous in antecessors:
                if id(previous) not in visited:
                    visited.add(id(previous))
                    stack.append(previous)
    return backward, forward

def encontraria(strategy, state):
    backward = set()
    forward = set()
    related = state.related - state.find("s0").related
    for work in state.related:
        backward |= (set(strategy.ref[work]) & related)
        forward |= (set(strategy.rev_ref[work]) & related)
    return backward, forward

class FinalSelection(State):
    
    def __init__(self, state):
        self.state = state
    
    @property
    def log(self):
        return []
    
    @property
    def dot(self):
        result = ["digraph G {", '  rankdir="RL";', ""]
        actions = Counter()

        stack = deque([self.state])
        visited = {id(self.state)}
        while stack:
            current = stack.popleft()
            current.final_selected = {
                work for work in current.related 
                if int(getattr(work, "final_selected", 0))
            }
            current.seed_set = {
                work for work in current.related 
                if int(getattr(work, "seed_set", 0))
            }
            
            current.excel = {
                work for work in current.visited 
                if int(getattr(work, "planilha_{}2016".format(current.name), 0))
            }
            current.excel_selected = {
                work for work in current.related 
                if int(getattr(work, "planilha_{}2016".format(current.name), 0))
            }
            
            current.delta_selected = {}
            current.delta_seed_set = {}
            options = [
                (" visited", len(current.visited)),
                (" selected", len(current.related)),  #  ("WorkSnowball", len(current.related)),
                #("selected", len(current.final_selected)),
                #("seed_set", len(current.seed_set)),
            ]
            
            #if current.planilha:
            #    options.append((" planilha", len(current.planilha)))
            #    options.append((" planilha selected", len(current.planilha_selected)))
            #    options.append((" duplicados", len(current.visited - current.planilha)))
            
            #if current.name == "scopus2016":
            #    current.name = "Scopus"
            
            result.append('  {0} [label="{0}\\n{1}"];'.format(
                current.name, 
                "\\n".join("{}: {}".format(key, value) for key, value in options)
            ))
            if current.previous:
                operation = current.previous[1]
                for element in current.previous[0]:
                    if operation == "union":
                        result.append('  {} -> {} [label="{}"];'.format(
                            current.name, element.name, operation
                        ))
                        
                        
                    else:
                        current.delta_selected = {
                            work for work in current.delta_related 
                            if int(getattr(work, "final_selected", 0))
                        }
                        current.delta_seed_set = {
                            work for work in current.delta_related 
                            if int(getattr(work, "seed_set", 0))
                        }
                        
                        options = [
                            (" visited", len(current.delta_visited)),
                            (" selected", len(current.delta_related)),
                            #("selected", len(current.delta_selected)),
                            #("seed_set", len(current.delta_seed_set)),
                        ]
                        result.append('  {} -> {} [label="{}\\n{}"];'.format(
                            current.name, element.name, operation,
                            "\\n".join("{}: {}".format(key, value) for key, value in options)
                        ))
                    if id(element) not in visited:
                        stack.append(element)
                        visited.add(id(element))
            result.append("")

        result.append("}")
        return '\n'.join(result)

    @property
    def draw(self):
        if SVG:
            return self._ipython_display_()
        from subprocess import Popen, PIPE as P
        from IPython.display import display
        bundle = {}

        dot = self.dot
        bundle['text/vnd.graphviz'] = dot

        try:
            kwargs = {} if os.name != 'nt' else {"creationflags": 0x08000000}
            p = Popen(['dot', '-T', "png"], stdout=P, stdin=P, stderr=P, **kwargs)
            image = p.communicate(dot.encode('utf-8'))[0]
            bundle['image/png'] = image
        except OSError as e:
            if e.errno != os.errno.ENOENT:
                raise

        bundle['text/plain'] = '\n'.join(map(str, self.log))
        display(bundle, raw=True)



def precision_recall(state, total, final, stop=""):
    # Precisao 0 quando nao visita nada
    array = [[
        "state", "precision", "recall", "fmeasure", 
        "final_precision", "final_recall", "final_fmeasure", 
        "operation", "delta_related", "delta_visited", "delta_selected",
        "related", "visited", "final_selected",
         "excel", "excel_selected", "duplicated",
        "accumulated_precision", "accumulated_recall", "accumulated_fmeasure",
        "final_accumulated_precision", "final_accumulated_recall", "final_accumulated_fmeasure"
    ]]
    FinalSelection(state).dot
    stack = deque([state])
    visited = {id(state)}
    while stack:
        current = stack.pop()
        accumulated_recall = len(current.related) / len(total)
        recall = len(current.delta_related) / len(total)
        final_accumulated_recall = len(current.final_selected) / len(final)
        final_recall = len(current.delta_selected) / len(final)
        try:
            accumulated_precision = len(current.related) / len(current.visited)
            precision = len(current.delta_related) / len(current.delta_visited)
        except ZeroDivisionError:
            precision = float('nan')
        try:
            final_accumulated_precision = len(current.final_selected) / len(current.visited)
            final_precision = len(current.delta_selected) / len(current.delta_visited)
        except ZeroDivisionError:
            final_precision = float('nan')
        try:
            accumulated_fmeasure = s.harmonic_mean([accumulated_precision, accumulated_recall])
            fmeasure = s.harmonic_mean([precision, recall])
        except ZeroDivisionError:
            fmeasure = float('nan')
        try:
            final_accumulated_fmeasure = s.harmonic_mean([final_accumulated_precision, final_accumulated_recall])
            final_fmeasure = s.harmonic_mean([final_precision, final_recall])
        except ZeroDivisionError:
            final_fmeasure = float('nan')
        excel = {
            work for work in current.visited 
            if int(getattr(work, "planilha_{}2016".format(current.name), 0))
        }
        excel_selected = {
            work for work in current.related 
            if int(getattr(work, "planilha_{}2016".format(current.name), 0))
        }     
            
        array.append([
            current.name,
            precision,
            recall,
            fmeasure,
            final_precision,
            final_recall,
            final_fmeasure,
            current.previous[1] if current.previous else "-",
            len(current.delta_related),
            len(current.delta_visited),
            len(current.delta_selected),
            len(current.related),
            len(current.visited),
            len(current.final_selected),
            len(excel),
            len(excel_selected),
            len(current.visited - excel) if excel else 0,
            accumulated_precision,
            accumulated_recall,
            accumulated_fmeasure,
            final_accumulated_precision,
            final_accumulated_recall,
            final_accumulated_fmeasure,
        ])
        if current.name == stop:
            break
        if current.previous:              
            antecessors = current.previous[0]
            for previous in antecessors:
                if id(previous) not in visited:
                    visited.add(id(previous))
                    stack.appendleft(previous)
    return array

# %% [markdown]
# # Strategies

# %% [markdown]
# ## Strategy 1 - Database Search (Search)

# %%
print ("\nTotal of selected studies = 11 (Seed Set) + 3 (Snowballing) =", len ({x for _, x in load_work_map_all_years() if x.category == "snowball"}))
# Out:
# Total of selected studies = 11 (Seed Set) + 3 (Snowballing) = 14

# %%
reload()
#TOTAL = {x for _, x in load_work_map_all_years() if getattr(x, "seed_set", 0)}
TOTAL = {x for _, x in load_work_map_all_years() if x.category == "snowball"}
FINAL = {x for _, x in load_work_map_all_years() if getattr(x, "final_selected", 0)}
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

arraysearch = []
for listdl in ("scopus_search","springer_search", "wiley_search","sciencedirect_search","acm_search","webofscience_search","ieee_search", "googlescholar_search"  ):
    search_title = {x for _, x in load_work_map_all_years() if getattr(x, listdl, 0)}
    recall_title = (len(search_title) / len(TOTAL))
    dl_row = [listdl[:-7]] + [len(search_title)] + [recall_title]
    arraysearch.append(dl_row)
    
#print (arraysearch)

strategy = Strategy(*busca("scopus2016", filter_function=filter_function)) # busca simples

state = strategy.initial
strategy.initial.visited

FinalSelection(state);

# %%
from snowballing.strategies import State

reload()
def busca_completa(libs, filter_function):
    union = None
    for dl in libs:
        strategy = Strategy(*busca(dl, filter_function=filter_function))
        strategy.initial.name = dl[:-4]
        if union is None:
            union = strategy.initial.derive("union", name="s0") 
        else:
            union.visited.update(strategy.initial.visited)
            union.related.update(strategy.initial.related)
            union.previous[0].append(strategy.initial)

    State.last_id = 0
    strategy.initial = union
    return strategy

#strategy = busca_completa(["springer2016"], filter_function)

strategy = busca_completa(["acm2016", "googlescholar2016", "ieee2016", "sciencedirect2016", "scopus2016", "springer2016", "webofscience2016", "wiley2016"], filter_function)
state = strategy.initial
final = FinalSelection(state)
    
print("\n \033[1mProvenance Graph - Strategy 1 - Database Search (Search)\033[0m")
final.draw
# Out:
#  Provenance Graph - Strategy 1 - Database Search (Search)

# %%
def salvar(state, arquivo):
    with open("{}.dot".format(arquivo), "w") as f:
        f.write(state.dot)
    # !dot -Tsvg {arquivo}.dot -o {arquivo}.svg
    # !inkscape -f {arquivo}.svg -e {arquivo}.png -d 300

# %%
#salvar(final, "E1final")

# %%
#strategy.initial.seed_set @ metakey_title
#strategy.initial.visited

# %%
from itertools import combinations
from functools import reduce
unicos = {}

for r in range(len(state.previous[0])):
    for comb in combinations(state.previous[0], r=r+1):
        others = [x for x in state.previous[0] if x not in comb]
        union = reduce(
            lambda x, y: x | y.related, others,
            set()
        )
        inter = reduce(
            lambda x, y: x & y.related, comb,
            state.related
        )
        # [x.related - set(inter) for x in comb]
        unicos[" & ".join(x.name for x in comb)] = (inter - union) @ metakey

print("\n\033[1mReport Strategy 2 - Seed Set of each Digital Library - Intersection \033[0m")   
unicos
# Out:
# Report Strategy 2 - Seed Set of each Digital Library - Intersection
# {'acm': [],
#  'acm & googlescholar': [],
#  'acm & googlescholar & ieee': [],
#  'acm & googlescholar & ieee & sciencedirect': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & springer': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & springer & webofscience': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & springer & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & webofscience': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & webofscience & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & scopus & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & springer': [],
#  'acm & googlescholar & ieee & sciencedirect & springer & webofscience': [],
#  'acm & googlescholar & ieee & sciencedirect & springer & webofscience & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & springer & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & webofscience': [],
#  'acm & googlescholar & ieee & sciencedirect & webofscience & wiley': [],
#  'acm & googlescholar & ieee & sciencedirect & wiley': [],
#  'acm & googlescholar & ieee & scopus': [],
#  'acm & googlescholar & ieee & scopus & springer': [],
#  'acm & googlescholar & ieee & scopus & springer & webofscience': [],
#  'acm & googlescholar & ieee & scopus & springer & webofscience & wiley': [],
#  'acm & googlescholar & ieee & scopus & springer & wiley': [],
#  'acm & googlescholar & ieee & scopus & webofscience': [],
#  'acm & googlescholar & ieee & scopus & webofscience & wiley': [],
#  'acm & googlescholar & ieee & scopus & wiley': [],
#  'acm & googlescholar & ieee & springer': [],
#  'acm & googlescholar & ieee & springer & webofscience': [],
#  'acm & googlescholar & ieee & springer & webofscience & wiley': [],
#  'acm & googlescholar & ieee & springer & wiley': [],
#  'acm & googlescholar & ieee & webofscience': [],
#  'acm & googlescholar & ieee & webofscience & wiley': [],
#  'acm & googlescholar & ieee & wiley': [],
#  'acm & googlescholar & sciencedirect': [],
#  'acm & googlescholar & sciencedirect & scopus': [],
#  'acm & googlescholar & sciencedirect & scopus & springer': [],
#  'acm & googlescholar & sciencedirect & scopus & springer & webofscience': [],
#  'acm & googlescholar & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'acm & googlescholar & sciencedirect & scopus & springer & wiley': [],
#  'acm & googlescholar & sciencedirect & scopus & webofscience': [],
#  'acm & googlescholar & sciencedirect & scopus & webofscience & wiley': [],
#  'acm & googlescholar & sciencedirect & scopus & wiley': [],
#  'acm & googlescholar & sciencedirect & springer': [],
#  'acm & googlescholar & sciencedirect & springer & webofscience': [],
#  'acm & googlescholar & sciencedirect & springer & webofscience & wiley': [],
#  'acm & googlescholar & sciencedirect & springer & wiley': [],
#  'acm & googlescholar & sciencedirect & webofscience': [],
#  'acm & googlescholar & sciencedirect & webofscience & wiley': [],
#  'acm & googlescholar & sciencedirect & wiley': [],
#  'acm & googlescholar & scopus': [],
#  'acm & googlescholar & scopus & springer': [],
#  'acm & googlescholar & scopus & springer & webofscience': [],
#  'acm & googlescholar & scopus & springer & webofscience & wiley': [],
#  'acm & googlescholar & scopus & springer & wiley': [],
#  'acm & googlescholar & scopus & webofscience': [],
#  'acm & googlescholar & scopus & webofscience & wiley': [],
#  'acm & googlescholar & scopus & wiley': [],
#  'acm & googlescholar & springer': [],
#  'acm & googlescholar & springer & webofscience': [],
#  'acm & googlescholar & springer & webofscience & wiley': [],
#  'acm & googlescholar & springer & wiley': [],
#  'acm & googlescholar & webofscience': [],
#  'acm & googlescholar & webofscience & wiley': [],
#  'acm & googlescholar & wiley': [],
#  'acm & ieee': [],
#  'acm & ieee & sciencedirect': [],
#  'acm & ieee & sciencedirect & scopus': [],
#  'acm & ieee & sciencedirect & scopus & springer': [],
#  'acm & ieee & sciencedirect & scopus & springer & webofscience': [],
#  'acm & ieee & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'acm & ieee & sciencedirect & scopus & springer & wiley': [],
#  'acm & ieee & sciencedirect & scopus & webofscience': [],
#  'acm & ieee & sciencedirect & scopus & webofscience & wiley': [],
#  'acm & ieee & sciencedirect & scopus & wiley': [],
#  'acm & ieee & sciencedirect & springer': [],
#  'acm & ieee & sciencedirect & springer & webofscience': [],
#  'acm & ieee & sciencedirect & springer & webofscience & wiley': [],
#  'acm & ieee & sciencedirect & springer & wiley': [],
#  'acm & ieee & sciencedirect & webofscience': [],
#  'acm & ieee & sciencedirect & webofscience & wiley': [],
#  'acm & ieee & sciencedirect & wiley': [],
#  'acm & ieee & scopus': [],
#  'acm & ieee & scopus & springer': [],
#  'acm & ieee & scopus & springer & webofscience': [],
#  'acm & ieee & scopus & springer & webofscience & wiley': [],
#  'acm & ieee & scopus & springer & wiley': [],
#  'acm & ieee & scopus & webofscience': [],
#  'acm & ieee & scopus & webofscience & wiley': [],
#  'acm & ieee & scopus & wiley': [],
#  'acm & ieee & springer': [],
#  'acm & ieee & springer & webofscience': [],
#  'acm & ieee & springer & webofscience & wiley': [],
#  'acm & ieee & springer & wiley': [],
#  'acm & ieee & webofscience': [],
#  'acm & ieee & webofscience & wiley': [],
#  'acm & ieee & wiley': [],
#  'acm & sciencedirect': [],
#  'acm & sciencedirect & scopus': [],
#  'acm & sciencedirect & scopus & springer': [],
#  'acm & sciencedirect & scopus & springer & webofscience': [],
#  'acm & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'acm & sciencedirect & scopus & springer & wiley': [],
#  'acm & sciencedirect & scopus & webofscience': [],
#  'acm & sciencedirect & scopus & webofscience & wiley': [],
#  'acm & sciencedirect & scopus & wiley': [],
#  'acm & sciencedirect & springer': [],
#  'acm & sciencedirect & springer & webofscience': [],
#  'acm & sciencedirect & springer & webofscience & wiley': [],
#  'acm & sciencedirect & springer & wiley': [],
#  'acm & sciencedirect & webofscience': [],
#  'acm & sciencedirect & webofscience & wiley': [],
#  'acm & sciencedirect & wiley': [],
#  'acm & scopus': [],
#  'acm & scopus & springer': [],
#  'acm & scopus & springer & webofscience': [],
#  'acm & scopus & springer & webofscience & wiley': [],
#  'acm & scopus & springer & wiley': [],
#  'acm & scopus & webofscience': [],
#  'acm & scopus & webofscience & wiley': [],
#  'acm & scopus & wiley': [],
#  'acm & springer': [],
#  'acm & springer & webofscience': [],
#  'acm & springer & webofscience & wiley': [],
#  'acm & springer & wiley': [],
#  'acm & webofscience': [],
#  'acm & webofscience & wiley': [],
#  'acm & wiley': [],
#  'googlescholar': ['stolfa2010a',
#   'grambow2013a',
#   'kabaale2016a',
#   'liao2005a',
#   'soydan2012a',
#   'grambow2012a',
#   'liao2005b'],
#  'googlescholar & ieee': [],
#  'googlescholar & ieee & sciencedirect': [],
#  'googlescholar & ieee & sciencedirect & scopus': [],
#  'googlescholar & ieee & sciencedirect & scopus & springer': [],
#  'googlescholar & ieee & sciencedirect & scopus & springer & webofscience': [],
#  'googlescholar & ieee & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'googlescholar & ieee & sciencedirect & scopus & springer & wiley': [],
#  'googlescholar & ieee & sciencedirect & scopus & webofscience': [],
#  'googlescholar & ieee & sciencedirect & scopus & webofscience & wiley': [],
#  'googlescholar & ieee & sciencedirect & scopus & wiley': [],
#  'googlescholar & ieee & sciencedirect & springer': [],
#  'googlescholar & ieee & sciencedirect & springer & webofscience': [],
#  'googlescholar & ieee & sciencedirect & springer & webofscience & wiley': [],
#  'googlescholar & ieee & sciencedirect & springer & wiley': [],
#  'googlescholar & ieee & sciencedirect & webofscience': [],
#  'googlescholar & ieee & sciencedirect & webofscience & wiley': [],
#  'googlescholar & ieee & sciencedirect & wiley': [],
#  'googlescholar & ieee & scopus': [],
#  'googlescholar & ieee & scopus & springer': [],
#  'googlescholar & ieee & scopus & springer & webofscience': [],
#  'googlescholar & ieee & scopus & springer & webofscience & wiley': [],
#  'googlescholar & ieee & scopus & springer & wiley': [],
#  'googlescholar & ieee & scopus & webofscience': [],
#  'googlescholar & ieee & scopus & webofscience & wiley': [],
#  'googlescholar & ieee & scopus & wiley': [],
#  'googlescholar & ieee & springer': [],
#  'googlescholar & ieee & springer & webofscience': [],
#  'googlescholar & ieee & springer & webofscience & wiley': [],
#  'googlescholar & ieee & springer & wiley': [],
#  'googlescholar & ieee & webofscience': [],
#  'googlescholar & ieee & webofscience & wiley': [],
#  'googlescholar & ieee & wiley': [],
#  'googlescholar & sciencedirect': [],
#  'googlescholar & sciencedirect & scopus': [],
#  'googlescholar & sciencedirect & scopus & springer': [],
#  'googlescholar & sciencedirect & scopus & springer & webofscience': [],
#  'googlescholar & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'googlescholar & sciencedirect & scopus & springer & wiley': [],
#  'googlescholar & sciencedirect & scopus & webofscience': [],
#  'googlescholar & sciencedirect & scopus & webofscience & wiley': [],
#  'googlescholar & sciencedirect & scopus & wiley': [],
#  'googlescholar & sciencedirect & springer': [],
#  'googlescholar & sciencedirect & springer & webofscience': [],
#  'googlescholar & sciencedirect & springer & webofscience & wiley': [],
#  'googlescholar & sciencedirect & springer & wiley': [],
#  'googlescholar & sciencedirect & webofscience': [],
#  'googlescholar & sciencedirect & webofscience & wiley': [],
#  'googlescholar & sciencedirect & wiley': [],
#  'googlescholar & scopus': ['ryu2008a', 'gazel2009a', 'gazel2012a'],
#  'googlescholar & scopus & springer': [],
#  'googlescholar & scopus & springer & webofscience': [],
#  'googlescholar & scopus & springer & webofscience & wiley': [],
#  'googlescholar & scopus & springer & wiley': [],
#  'googlescholar & scopus & webofscience': [],
#  'googlescholar & scopus & webofscience & wiley': [],
#  'googlescholar & scopus & wiley': [],
#  'googlescholar & springer': ['rungratri2008a'],
#  'googlescholar & springer & webofscience': [],
#  'googlescholar & springer & webofscience & wiley': [],
#  'googlescholar & springer & wiley': [],
#  'googlescholar & webofscience': [],
#  'googlescholar & webofscience & wiley': [],
#  'googlescholar & wiley': [],
#  'ieee': [],
#  'ieee & sciencedirect': [],
#  'ieee & sciencedirect & scopus': [],
#  'ieee & sciencedirect & scopus & springer': [],
#  'ieee & sciencedirect & scopus & springer & webofscience': [],
#  'ieee & sciencedirect & scopus & springer & webofscience & wiley': [],
#  'ieee & sciencedirect & scopus & springer & wiley': [],
#  'ieee & sciencedirect & scopus & webofscience': [],
#  'ieee & sciencedirect & scopus & webofscience & wiley': [],
#  'ieee & sciencedirect & scopus & wiley': [],
#  'ieee & sciencedirect & springer': [],
#  'ieee & sciencedirect & springer & webofscience': [],
#  'ieee & sciencedirect & springer & webofscience & wiley': [],
#  'ieee & sciencedirect & springer & wiley': [],
#  'ieee & sciencedirect & webofscience': [],
#  'ieee & sciencedirect & webofscience & wiley': [],
#  'ieee & sciencedirect & wiley': [],
#  'ieee & scopus': [],
#  'ieee & scopus & springer': [],
#  'ieee & scopus & springer & webofscience': [],
#  'ieee & scopus & springer & webofscience & wiley': [],
#  'ieee & scopus & springer & wiley': [],
#  'ieee & scopus & webofscience': [],
#  'ieee & scopus & webofscience & wiley': [],
#  'ieee & scopus & wiley': [],
#  'ieee & springer': [],
#  'ieee & springer & webofscience': [],
#  'ieee & springer & webofscience & wiley': [],
#  'ieee & springer & wiley': [],
#  'ieee & webofscience': [],
#  'ieee & webofscience & wiley': [],
#  'ieee & wiley': [],
#  'sciencedirect': [],
#  'sciencedirect & scopus': [],
#  'sciencedirect & scopus & springer': [],
#  'sciencedirect & scopus & springer & webofscience': [],
#  'sciencedirect & scopus & springer & webofscience & wiley': [],
#  'sciencedirect & scopus & springer & wiley': [],
#  'sciencedirect & scopus & webofscience': [],
#  'sciencedirect & scopus & webofscience & wiley': [],
#  'sciencedirect & scopus & wiley': [],
#  'sciencedirect & springer': [],
#  'sciencedirect & springer & webofscience': [],
#  'sciencedirect & springer & webofscience & wiley': [],
#  'sciencedirect & springer & wiley': [],
#  'sciencedirect & webofscience': [],
#  'sciencedirect & webofscience & wiley': [],
#  'sciencedirect & wiley': [],
#  'scopus': [],
#  'scopus & springer': [],
#  'scopus & springer & webofscience': [],
#  'scopus & springer & webofscience & wiley': [],
#  'scopus & springer & wiley': [],
#  'scopus & webofscience': [],
#  'scopus & webofscience & wiley': [],
#  'scopus & wiley': [],
#  'springer': [],
#  'springer & webofscience': [],
#  'springer & webofscience & wiley': [],
#  'springer & wiley': [],
#  'webofscience': [],
#  'webofscience & wiley': [],
#  'wiley': []}

# %%
print("\n\033[1mReport Strategy 2 - Seed Set \033[0m") 
len(sum((v for k, v in unicos.items()), []))
# Out:
# Report Strategy 2 - Seed Set
# 11

# %%
print("\n\033[1mReport Strategy 2 - Unique in the intersection \033[0m") 
len(sum((v for k, v in unicos.items() if not "&" in k), []))
# Out:
# Report Strategy 2 - Unique in the intersection
# 7

# %%
print("\n\033[1mReport Strategy 2 - Empty set \033[0m") 
[k for k, v in unicos.items() if v == [] and "&" not in k]
# Out:
# Report Strategy 2 - Empty set
# ['acm', 'ieee', 'sciencedirect', 'scopus', 'springer', 'webofscience', 'wiley']

# %%
array = []
name = "Search"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df = df.round(4)
df.columns = df.iloc[-1]
df = df.drop(df.index[[-1]])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
#df = df.drop(df.index[[-1,8]]) #exclude row first=-1 and last=7=s0
df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
        

df1 = df[["state","visited", "related", "precision", "recall", "fmeasure" ]]
df1.columns = ['Digital Library', 'Visited', 'Selected', 'Precision %', 'Recall %', 'F-Measure %']

df1 = df1.sort_values('Digital Library', ascending=True)

#print (df1.to_string(index=False))
#df1_style.hide_index()

df2 = df[["visited", "related","accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df2.columns = ['Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']
df2 = df2.loc[df['state'] == 's0']

df1 = df1.drop(df.index[[-1,8]])

df2_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])
df2_style.hidden_index = True
df2_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

dfE1 = df2_style
dfE1r =df1

def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: gold' if v else '' for v in is_max]

import seaborn as sns
sns.set_style(style='white')  

cm = sns.light_palette("green", as_cmap=True)
#df2_style.background_gradient(cmap=cm, subset=['Precision %', 'Recall %', 'F-Measure %']).highlight_max(subset=['Precision %', 'Recall %', 'F-Measure %']).set_table_styles(([
#    dict(selector="th", props=[("text-align", "center")]),
#]))

df2_style.background_gradient(cmap=cm, subset=['Precision %', 'Recall %', 'F-Measure %']).set_table_styles(([
    dict(selector="th", props=[("text-align", "center")]),
]))
df2_style.apply(highlight_max, subset=['Precision %', 'Recall %', 'F-Measure %'])

df2_style.highlight_null(null_color='crimson')

def color_value_zero(val):
    color = 'green' if val == 0 else 'black'
    return 'color: %s' % color

df2_style.applymap(color_value_zero, subset=pd.IndexSlice[:, ['Precision %', 'Recall %', 'F-Measure %']])

np.warnings.filterwarnings('ignore')

print("\n\033[1mReport Strategy 1 - Database Search (Search) \033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")
df2_style
# Out:
# Report Strategy 1 - Database Search (Search)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_d217a6ae_de0d_11e8_b88b_ac7289426fde th {
#           text-align: center;
#     }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col3 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             background-color:  crimson;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col4 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow0_col5 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col3 {
#             text-align:  center;
#             background-color:  #57b057;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col4 {
#             text-align:  center;
#             background-color:  #008000;
#             background-color:  gold;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow1_col5 {
#             text-align:  center;
#             background-color:  #43a543;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col3 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             background-color:  crimson;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col4 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow2_col5 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col3 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col4 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow3_col5 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col3 {
#             text-align:  center;
#             background-color:  #008000;
#             background-color:  gold;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col4 {
#             text-align:  center;
#             background-color:  #a7dda7;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow4_col5 {
#             text-align:  center;
#             background-color:  #008000;
#             background-color:  gold;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col3 {
#             text-align:  center;
#             background-color:  #89cc89;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col4 {
#             text-align:  center;
#             background-color:  #d1f4d1;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow5_col5 {
#             text-align:  center;
#             background-color:  #8bcd8b;
#             : ;
#             : ;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col3 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             background-color:  crimson;
#             color:  black;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col4 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow6_col5 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col0 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col1 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col2 {
#             text-align:  center;
#             : ;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col3 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col4 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }    #T_d217a6ae_de0d_11e8_b88b_ac7289426fderow7_col5 {
#             text-align:  center;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#             color:  green;
#         }</style>
# <table id="T_d217a6ae_de0d_11e8_b88b_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Digital Library</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>

# %%
df.to_excel("estrategia1.xlsx")

# %%
df1.plot.bar(y=['Precision %', 'Recall %', 'F-Measure %'], alpha=0.75, rot=60)
ax = plt.gca()
ax.set_title("Measures\n")
ax.legend(loc = 'best')
ax.get_legend().set_bbox_to_anchor((1.0, 1.0))
ax.set_xticklabels(df1['Digital Library'])
plt.xlabel("\nDigital Library")
plt.ylabel("Percent (%)\n")
print ('\n \033[1m Bar Chart Strategy 1 \033[0m')
# Out:
#   Bar Chart Strategy 1

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=False)

df1.plot.bar(y=['Precision %'], color="navy", alpha=0.75, rot=60, ax=ax1)
ax = ax1
ax.set_title("Precision\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Digital Library'])
ax.set_ylabel("Percent (%)")
print ('\n \033[1m Bar Chart Strategy 1 \033[0m')

df1.plot.bar(y=['Recall %'], color="green", alpha=0.75, rot=60, ax=ax2)
ax = ax2
ax.set_title("Recall\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Digital Library'])
ax.set_xlabel("\nDigital Library")
ax.set_ylabel("\nPercent (%)")

df1.plot.bar(y=['F-Measure %'], color="crimson", alpha=0.75, rot=60, ax=ax3)
ax = ax3
ax.set_title("F-Measure\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Digital Library'])
ax.set_ylabel("Percent (%)")
ax.grid(False)
f.set_size_inches(15, 4)

f.savefig("measurestrategy1.png")
# Out:
#   Bar Chart Strategy 1

# %%
#df1.plot.bar(y=['Precision %'], color="navy", alpha=0.75, rot=60)
#ax = plt.gca()
#ax.set_title("Precision\n")
#ax.legend_.remove()
#ax.set_xticklabels(df1['Digital Library'])
#plt.xlabel("\nDigital Library")
#plt.ylabel("Percent (%)\n")
#print ('\n \033[1m Bar Chart Strategy 1 \033[0m')

# %%
#df1.plot.bar(y=['Recall %'], color="green", alpha=0.75, rot=60)
#ax = plt.gca()
#ax.set_title("Recall\n")
#ax.legend_.remove()
#ax.set_xticklabels(df1['Digital Library'])
#plt.xlabel("\nDigital Library")
#plt.ylabel("Percent (%)\n")
#print ('\n \033[1m Bar Chart Strategy 1 \033[0m')

# %%
#df1.plot.bar(y=['F-Measure %'], color="crimson", alpha=0.75, rot=60)
#ax = plt.gca()
#ax.set_title("F-Measure\n")
#ax.legend_.remove()
#ax.set_xticklabels(df1['Digital Library'])
#plt.xlabel("\nDigital Library")
#plt.ylabel("Percent (%)\n")
#ax.grid(False)
#print ('\n \033[1m Bar Chart Strategy 1 \033[0m')

# %%
dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

df2_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df2_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

print("\n \033[1mReport Strategy 1 - Measures of Strategy - Union of all digital libraries (accumulated) \033[0m")
df2_style.hidden_index = True
df2_style
# Out:
#  Report Strategy 1 - Measures of Strategy - Union of all digital libraries (accumulated)
# <style  type="text/css" >
#     #T_d99446b8_de0d_11e8_93fc_ac7289426fde th {
#           text-align: center;
#     }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_d99446b8_de0d_11e8_93fc_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col0" class="data row0 col0" >Search</td>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col1" class="data row0 col1" >480</td>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col3" class="data row0 col3" >2.29</td>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_d99446b8_de0d_11e8_93fc_ac7289426fderow0_col5" class="data row0 col5" >4.45</td>
#     </tr></tbody>
# </table>

# %%
df3 = df[["state","visited", "related", "excel", "excel_selected", "duplicated"]]
df3.columns = ['Digital Library', 'Visited', 'Selected', 'Excel', 'Excel Selected', 'Duplicated']
df3 = df3.drop(df.index[[-1,8]]) #remove ultima linha que contem o state s0.

df3 = df3.sort_values('Digital Library', ascending=True)

df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])
df3_style.hidden_index = True
print("\n\033[1mReport Strategy 1 - Total of papers retrieved from Excel and Duplicates.\033[0m")
print("\nVisited = Excel + Duplicates")
print("Selected = Papers selected in the SLR")
print("Excel =  Papers retrieved from Excel provided by authors")
print("Excel Selected =  Papers selected in the SLR and retrieved from Excel provided by authors")
print("Duplicated =  Papers identified as duplicate")

df3_style
# Out:
# Report Strategy 1 - Total of papers retrieved from Excel and Duplicates.
#
# Visited = Excel + Duplicates
# Selected = Papers selected in the SLR
# Excel =  Papers retrieved from Excel provided by authors
# Excel Selected =  Papers selected in the SLR and retrieved from Excel provided by authors
# Duplicated =  Papers identified as duplicate
# <style  type="text/css" >
#     #T_d9bf2e9c_de0d_11e8_a079_ac7289426fde th {
#           text-align: center;
#     }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow6_col5 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col0 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col1 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col2 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col3 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col4 {
#             text-align:  center;
#         }    #T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow7_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Digital Library</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Excel</th>
#         <th class="col_heading level0 col4" >Excel Selected</th>
#         <th class="col_heading level0 col5" >Duplicated</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col0" class="data row0 col0" >acm</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col1" class="data row0 col1" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col2" class="data row0 col2" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col3" class="data row0 col3" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col4" class="data row0 col4" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow0_col5" class="data row0 col5" >0</td>
#     </tr>    <tr>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col0" class="data row1 col0" >googlescholar</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col1" class="data row1 col1" >466</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col2" class="data row1 col2" >11</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col3" class="data row1 col3" >466</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col4" class="data row1 col4" >11</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col0" class="data row2 col0" >ieee</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col1" class="data row2 col1" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col2" class="data row2 col2" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col3" class="data row2 col3" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col4" class="data row2 col4" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col0" class="data row3 col0" >sciencedirect</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col1" class="data row3 col1" >21</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col2" class="data row3 col2" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col3" class="data row3 col3" >21</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col4" class="data row3 col4" >0</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow3_col5" class="data row3 col5" >0</td>
#     </tr>    <tr>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col0" class="data row4 col0" >scopus</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col1" class="data row4 col1" >79</td>
#         <td id="T_d9bf2e9c_de0d_11e8_a079_ac7289426fderow4_col2" class="data row4 col2" >3</td>

# %%
lista = [work.entrytype for work in TOTAL] #state.related
df = pd.DataFrame (lista)

ax = df.apply(pd.value_counts).plot(kind="bar", color = 'green',legend = False, alpha=0.75, rot=0)
ax.set_title("Publication Type of Selected\n")

ax.yaxis.set_major_locator(plt.MaxNLocator(6))

ax.grid(False)

plt.xlabel("\n Publication Type")
plt.ylabel("\n Score\n")

print ('\n \033[1m Bar Chart Publications Type - Strategy 1 \n \033[0m')

for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() * 1.000, p.get_height() * 1.005 ), ha='center', va='center', xytext=(25, 3), textcoords='offset points')
# Out:
#   Bar Chart Publications Type - Strategy 1

# %%
listayear = [work.year for work in TOTAL] # in state.related
df = pd.DataFrame (listayear)
df
df = df[[0]] 
df.columns = ['Selected']
df1 = df.sort_values('Selected', ascending=False)
df2 = df1.groupby(['Selected']).size().reset_index()
df2.sort_values('Selected', ascending=False)
df2

df2.plot.bar(x= "Selected", y=[0], color = 'purple', legend = False, alpha=0.75, rot=0)
ax = plt.gca()
ax.set_title("Publication Year of Selected\n")

ax.yaxis.set_major_locator(plt.MaxNLocator(2))

ax.grid(False)

plt.xlabel("\n Publication Year")
plt.ylabel("\nScore\n")
print ('\n \033[1m Bar Chart Publications Year - Strategy 1 \n \033[0m')

for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() * 1.000, p.get_height() * 1.005 ), ha='center', va='center', xytext=(12, 3), textcoords='offset points')
# Out:
#   Bar Chart Publications Year - Strategy 1

# %% [markdown]
# ## Strategy 2 - Database Search + Snowballing of Wohlin Guideline (Search + SB)

# %%
reload()
TOTAL = {x for _, x in load_work_map_all_years() if x.category == "snowball"}
FINAL = {x for _, x in load_work_map_all_years() if getattr(x, "final_selected", 0)}
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = busca_completa(["acm2016", "googlescholar2016", "ieee2016", "sciencedirect2016", "scopus2016", "springer2016", "webofscience2016", "wiley2016"], filter_function)
state = strategy.sfbu()
final = FinalSelection(state)

print("\n \033[1mProvenance Graph - Strategy 2 - Database Search + Snowballing of Wohlin Guideline (Search + SB)\033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 2 - Database Search + Snowballing of Wohlin Guideline (Search + SB)

# %%
#salvar(final, "E2final")

# %%
name = "Search + SB"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df

#d_decimals = 4    
#for coluna in ['precision', 'recall', 'fmeasure', 'final_precision', 'final_recall', 'final_fmeasure','delta_related', 'delta_visited', 'delta_selected','related', 'visited', 'final_selected','accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure','final_accumulated_precision', 'final_accumulated_recall', 'final_accumulated_fmeasure']:
#      df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals))
#df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
    
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Digital Library/State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']

df2 = df1.loc[df['operation'] == '-']
df2 = df2.sort_values('Digital Library/State', ascending=True)

df3 = df1.loc[df['operation'] != '-']
df3 = df3.sort_values('Digital Library/State', ascending=True)

df4 = pd.concat([df2, df3], ignore_index=True)

df4_style = df4.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df4_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})
df4_style.hidden_index = True
print("\n\033[1mReport Strategy 2 - Database Search + Snowballing of Wohlin Guideline (Search + SB)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")
df4_style
# Out:
# Report Strategy 2 - Database Search + Snowballing of Wohlin Guideline (Search + SB)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fde th {
#           text-align: center;
#     }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow4_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col9 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col10 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow5_col11 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col5 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col6 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col7 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_11e8_ba1c_ac7289426fderow6_col8 {
#             text-align:  center;
#         }    #T_e93c8fdc_de0d_

# %%
#df2 = df[["visited", "related","accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
#df2.columns = ['Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %'] 
#indexdf = df.index[-1]
#df3 = df2.loc[df.index == indexdf]

dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf]    
    
    
df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df3_style.hidden_index = True
print("\n \033[1mReport Strategy 2 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 2 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_eb315712_de0d_11e8_aa25_ac7289426fde th {
#           text-align: center;
#     }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_eb315712_de0d_11e8_aa25_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col0" class="data row0 col0" >Search + SB</td>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col1" class="data row0 col1" >932</td>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col2" class="data row0 col2" >14</td>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col3" class="data row0 col3" >1.50</td>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col4" class="data row0 col4" >100.00</td>
#         <td id="T_eb315712_de0d_11e8_aa25_ac7289426fderow0_col5" class="data row0 col5" >2.96</td>
#     </tr></tbody>
# </table>

# %%
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 2',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['lee2009a', 'lee2008a', 'soydan2006a']
# Forward ['soydan2006a']

# %%
# ---- Grafico de linha para Somente Union 
df = df.loc[df['operation'] == 'union'].reset_index(drop=True)
fig = plt.figure()
df['accumulated_precision'].plot(legend=True)
df['accumulated_recall'].plot(legend=True)
df['accumulated_fmeasure'].plot(legend=True)
ax = plt.gca()
ax.set_xticklabels(df["state"] + "\n" + df["operation"])
ax.legend(loc = 'best')
ax.get_legend().set_bbox_to_anchor((1.0, 1.0))
plt.xticks(np.arange(0, len(df), 1.0), rotation='horizontal')
plt.xlabel("\nState Union")
plt.ylabel("Percent (%)\n")
ax.set_title("Accumulated Measures - Strategy 2\n", fontsize="14");
ax.grid(False)
plt.tight_layout()

# %% [markdown]
# ## Strategy 3 - Informal Search (Google Scholar) + Snowballing of Wohlin Guideline = (GS + SB)

# %%
reload()
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = Strategy(*busca("scholar2016", filter_function=filter_function))
state = strategy.sfbu()

if strategy.initial.name == "s0":
    strategy.initial.name = "s0: googlescholar"

final = FinalSelection(state)
print("\n \033[1mProvenance Graph - Strategy 3 - Informal Search (Google Scholar) + Snowballing of Wohlin Guideline = (GS + SB)\033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 3 - Informal Search (Google Scholar) + Snowballing of Wohlin Guideline = (GS + SB)

# %%
#salvar(final, "E3final")

# %%
name = "GS + SB"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df


d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
      
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Scholar=s0 /State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']

df1 = df1.sort_values('Scholar=s0 /State', ascending=True)

df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})

df1_style.hidden_index = True
print("\n\033[1mReport Strategy 3 - Informal Search in Google Scholar + Snowballing of Wohlin Guideline = (GS + SB)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")

df1_style
# Out:
# Report Strategy 3 - Informal Search in Google Scholar + Snowballing of Wohlin Guideline = (GS + SB)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fde th {
#           text-align: center;
#     }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow4_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col9 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col10 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow5_col11 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col5 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col6 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col7 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_11e8_b8ce_ac7289426fderow6_col8 {
#             text-align:  center;
#         }    #T_24d9fdbe_de0e_

# %%
#df2 = df[["visited", "related","accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
#df2.columns = ['Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']
#indexdf = df.index[-1]
#df3 = df2.loc[df.index == indexdf]

dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf] 
    
    

df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})
df3_style.hidden_index = True
print("\n \033[1mReport Strategy 3 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 3 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_2ab47cba_de0e_11e8_8a50_ac7289426fde th {
#           text-align: center;
#     }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_2ab47cba_de0e_11e8_8a50_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col0" class="data row0 col0" >GS + SB</td>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col1" class="data row0 col1" >489</td>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col3" class="data row0 col3" >2.25</td>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_2ab47cba_de0e_11e8_8a50_ac7289426fderow0_col5" class="data row0 col5" >4.37</td>
#     </tr></tbody>
# </table>

# %%
strategy.initial.name = "s0"
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 3',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['rungratri2008a', 'lee2008a', 'gazel2009a', 'soydan2006a']
# Forward ['ryu2008a', 'gazel2009a', 'grambow2013a', 'soydan2006a', 'soydan2012a', 'grambow2012a']

# %% [markdown]
# ## Strategy 4 - Scopus + Snowballing of Wohlin Guideline (Scopus + SB)

# %%
reload()
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = Strategy(*busca("scopus2016", filter_function=filter_function))

state = strategy.sfbu()

if strategy.initial.name == "s0":
    strategy.initial.name = "s0 : scopus"
    
final = FinalSelection(state)
print("\n \033[1mProvenance Graph - Strategy 4 - Scopus + Snowballing (Guideline Wohlin) \033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 4 - Scopus + Snowballing (Guideline Wohlin)

# %%
#salvar(final, "E4final")

# %%
name = "Scopus + SB"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
    
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Scopus=s0 /State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']
                           

#df1["state2"] = df1["Scopus=s0 /State"].copy().apply(lambda x: int(x[1:3]))

df1 = df1.copy()

df1["state2"] = df1.loc[:,"Scopus=s0 /State"].copy().apply(lambda x: int(x[1:3]))
df1 = df1.sort_values('state2', ascending=True)
df1.drop('state2', axis=1, inplace=True)


df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})

df1_style.hidden_index = True

print("\n\033[1mReport Strategy 4 - Scopus + Snowballing of Wohlin Guideline (Scopus + SB)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")

df1_style
# Out:
# Report Strategy 4 - Scopus + Snowballing of Wohlin Guideline (Scopus + SB)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_53671164_de0e_11e8_be54_ac7289426fde th {
#           text-align: center;
#     }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow4_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col9 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col10 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow5_col11 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col5 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col6 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col7 {
#             text-align:  center;
#         }    #T_53671164_de0e_11e8_be54_ac7289426fderow6_col8 {
#             text-align:  center;
#         }    #T_53671164_de0e_

# %%
dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf] 


df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df3_style.hidden_index = True
print("\n \033[1mReport Strategy 4 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 4 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fde th {
#           text-align: center;
#     }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col0" class="data row0 col0" >Scopus + SB</td>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col1" class="data row0 col1" >502</td>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col3" class="data row0 col3" >2.19</td>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_5a9fcf0a_de0e_11e8_bff4_ac7289426fderow0_col5" class="data row0 col5" >4.26</td>
#     </tr></tbody>
# </table>

# %%
strategy.initial.name = "s0"
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 4',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['soydan2006a', 'liao2005a', 'lee2008a', 'lee2009a', 'rungratri2008a']
# Forward ['soydan2012a', 'grambow2012a', 'grambow2013a']

# %% [markdown]
# ## Strategy 5 - Scopus + Parallel Snowballing of Paper ESEM2017 (Scopus + BS // FS)

# %%
reload()
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = Strategy(*busca("scopus2016", filter_function=filter_function))
state = strategy.s2bbff2u()

if strategy.initial.name == "s0":
    strategy.initial.name = "s0: scopus"
final =  FinalSelection(state)   
print("\n \033[1mProvenance Graph - Strategy 5 - Scopus + Parallel Snowballing of Paper ESEM2017 (Scopus + BS // FS) \033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 5 - Scopus + Parallel Snowballing of Paper ESEM2017 (Scopus + BS // FS)

# %%
#salvar(final, "E5final")

# %%
name = "Scopus + BS // FS"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
      
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Scopus=s0 /State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']

df1 = df1.sort_values('Scopus=s0 /State', ascending=True)
   
df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})

df1_style.hidden_index = True
print("\n\033[1mReport Strategy 5 - Scopus + Parallel Snowballing of Paper ESEM2017 (Scopus + BS // FS)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")

df1_style
# Out:
# Report Strategy 5 - Scopus + Parallel Snowballing of Paper ESEM2017 (Scopus + BS // FS)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_60cfc7cc_de0e_11e8_a224_ac7289426fde th {
#           text-align: center;
#     }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow4_col11 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col6 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col7 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col8 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col9 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col10 {
#             text-align:  center;
#         }    #T_60cfc7cc_de0e_11e8_a224_ac7289426fderow5_col11 {
#             text-align:  center;
#         }</style>
# <table id="T_60cfc7cc_de0e_11e8_a224_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scopus=s0 /State</th>
#         <th class="col_heading level0 col1" >Delta Visited</th>
#         <th class="col_heading level0 col2" >Delta Selected</th>
#         <th class="col_heading level0 col3" >Delta Precision%</th>
#         <th class="col_heading level0 col4" >Delta Recall%</th>
#         <th class="col_heading level0 col5" >Delta F_Measure%</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accumulated Visited</th>
#         <th class="col_heading level0 col8" >Accumulated Selected</th>
#         <th class="col_heading level0 col9" >Accumulated Precision%</th>
#         <th class="col_heading level0 col10" >Accumulated Recall%</th>
#         <th class="col_heading level0 col11" >Accumulated F_Me

# %%
dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf] 

df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df3_style.hidden_index = True
print("\n \033[1mReport Strategy 5 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 5 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_63075f76_de0e_11e8_9408_ac7289426fde th {
#           text-align: center;
#     }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_63075f76_de0e_11e8_9408_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_63075f76_de0e_11e8_9408_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col0" class="data row0 col0" >Scopus + BS // FS</td>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col1" class="data row0 col1" >242</td>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col2" class="data row0 col2" >9</td>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col3" class="data row0 col3" >3.72</td>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col4" class="data row0 col4" >64.29</td>
#         <td id="T_63075f76_de0e_11e8_9408_ac7289426fderow0_col5" class="data row0 col5" >7.03</td>
#     </tr></tbody>
# </table>

# %%
strategy.initial.name = "s0"
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 5',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['soydan2006a', 'liao2005a', 'lee2008a', 'lee2009a', 'rungratri2008a']
# Forward ['soydan2012a']

# %%
df1 = df.loc[df['operation'] == 'backward']

df1.plot.bar(y=["accumulated_precision","accumulated_recall","accumulated_fmeasure"], alpha=0.75, rot=0)
ax = plt.gca()
ax.set_title("Scopus + Backward Snowballing\n")
ax.legend(loc = 'best')
ax.get_legend().set_bbox_to_anchor((1.45, 1.0))
ax.set_xticklabels(df1["state"])
plt.xlabel("\nBackward - Iteration")
plt.ylabel("Percent (%)\n")
ax.grid(False)
print ('\n \033[1m Bar Chart Strategy 5 \033[0m')

plt.tight_layout()
# Out:
#   Bar Chart Strategy 5

# %%
#df1 = df.loc[df['operation'] == 'backward'] 

#df1.plot.bar(y=["accumulated_recall"], color='green', alpha=0.75, rot=0)
#ax = plt.gca()
#ax.set_title("Scopus + Backward Snowballing (Recall)\n")
#ax.legend(loc = 'best')
#ax.get_legend().set_bbox_to_anchor((1.45, 1.0))
#ax.set_xticklabels(df1["state"])
#plt.xlabel("\nBackward - Iteration")
#plt.ylabel("Percent (%)\n")
#ax.grid(False)
#print ('\n \033[1m Bar Chart Strategy 5 \033[0m')

#plt.tight_layout()

# %%
df2 = df.loc[df['operation'] == 'forward'].reset_index(drop=True)

df2.plot.bar(y=["accumulated_precision","accumulated_recall","accumulated_fmeasure"], alpha=0.75, rot=0)
ax = plt.gca()
ax.set_title("Scopus + Forward Snowballing\n")
ax.legend(loc = 'best')
ax.get_legend().set_bbox_to_anchor((1.0, 1.0))
ax.set_xticklabels(df2["state"])
plt.xlabel("Forward - Iteration")
plt.ylabel("Percent (%)\n")
print ('\n \033[1m Bar Chart Strategy 5 \033[0m')

plt.tight_layout()
# Out:
#   Bar Chart Strategy 5

# %%
#df2 = df.loc[df['operation'] == 'forward'].reset_index(drop=True)

#df2.plot.bar(y=["accumulated_recall"], color='green', alpha=0.75, rot=0)
#ax = plt.gca()
#ax.set_title("Scopus + Forward Snowballing (Recall) \n")
#ax.legend(loc = 'best')
#ax.get_legend().set_bbox_to_anchor((1.0, 1.0))
#ax.set_xticklabels(df2["state"])
#plt.xlabel("Forward - Iteration")
#plt.ylabel("Percent (%)\n")
#print ('\n \033[1m Bar Chart Strategy 5 \033[0m')

#plt.tight_layout()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

df1 = df.loc[df['operation'] == 'backward'] 
df1.plot.bar(y=["accumulated_recall"], color="navy", alpha=0.75, rot=0, ax=ax1)
ax = ax1
ax.set_title("Scopus + Backward Snowballing (Recall)\n")
ax.legend_.remove()
ax.set_xticklabels(df1["state"])
ax.set_xlabel("\nBackward - Iteration\n")
ax.set_ylabel("Percent (%)\n")
print ('\n \033[1m Bar Chart Strategy 5 (Scopus + BS // FS) \033[0m')

df1 = df.loc[df['operation'] == 'forward'].reset_index(drop=True)
df1.plot.bar(y=["accumulated_recall"], color="green", alpha=0.75, rot=0, ax=ax2)
ax = ax2
ax.set_title("Scopus + Forward Snowballing (Recall)\n")
ax.legend_.remove()
ax.set_xticklabels(df1["state"])
ax.set_xlabel("\nForward - Iteration")
ax.set_ylabel("Percent (%)")
#ax.set_ylabel("Percent (%)\n")


ax.grid(False)
f.set_size_inches(15, 4)

f.savefig("recallBSFS.png")
# Out:
#   Bar Chart Strategy 5 (Scopus + BS // FS)

# %% [markdown]
# ## Strategy 6 - Scopus + Sequential Snowballing (Scopus + BS + FS)

# %%
reload()
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = Strategy(*busca("scopus2016", filter_function=filter_function))
state = strategy.bbff()

if strategy.initial.name == "s0":
    strategy.initial.name = "s0: scopus"
final = FinalSelection(state)
print("\n \033[1mProvenance Graph - Strategy 6 - Scopus + Sequential Snowballing (Scopus + BS + FS) \033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 6 - Scopus + Sequential Snowballing (Scopus + BS + FS)

# %%
#salvar(final, "E6final")

# %%
name = "Scopus + BS + FS"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
      
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Scopus=s0 /State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']

df1 = df1.sort_values('Scopus=s0 /State', ascending=True)

df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})

df1_style.hidden_index = True
#print (strategy_row)
print("\n\033[1mReport Strategy 6 - Scopus + Sequential Snowballing (Scopus + BS + FS)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")

df1_style
# Out:
# Report Strategy 6 - Scopus + Sequential Snowballing (Scopus + BS + FS)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_7135925c_de0e_11e8_a2f7_ac7289426fde th {
#           text-align: center;
#     }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_7135925c_de0e_11e8_a2f7_ac7289426fderow4_col11 {
#             text-align:  center;
#         }</style>
# <table id="T_7135925c_de0e_11e8_a2f7_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scopus=s0 /State</th>
#         <th class="col_heading level0 col1" >Delta Visited</th>
#         <th class="col_heading level0 col2" >Delta Selected</th>
#         <th class="col_heading level0 col3" >Delta Precision%</th>
#         <th class="col_heading level0 col4" >Delta Recall%</th>
#         <th class="col_heading level0 col5" >Delta F_Measure%</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accumulated Visited</th>
#         <th class="col_heading level0 col8" >Accumulated Selected</th>
#         <th class="col_heading level0 col9" >Accumulated Precision%</th>
#         <th class="col_heading level0 col10" >Accumulated Recall%</th>
#         <th class="col_heading level0 col11" >Accumulated F_Measure%</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col0" class="data row0 col0" >s0: scopus</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col1" class="data row0 col1" >79</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col2" class="data row0 col2" >3</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col3" class="data row0 col3" >3.80</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col4" class="data row0 col4" >21.43</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col5" class="data row0 col5" >6.45</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col6" class="data row0 col6" >-</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col7" class="data row0 col7" >79</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col8" class="data row0 col8" >3</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col9" class="data row0 col9" >3.80</td>
#         <td id="T_7135925c_de0e_11e8_a2f7_ac7289426fderow0_col10" class="data row0 col10" >21.43</td>
#         <td id="T_71

# %%
dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf] 


df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})
df3_style.hidden_index = True
print("\n \033[1mReport Strategy 6 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 6 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_7324f392_de0e_11e8_8fdc_ac7289426fde th {
#           text-align: center;
#     }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_7324f392_de0e_11e8_8fdc_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col0" class="data row0 col0" >Scopus + BS + FS</td>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col1" class="data row0 col1" >424</td>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col3" class="data row0 col3" >2.59</td>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_7324f392_de0e_11e8_8fdc_ac7289426fderow0_col5" class="data row0 col5" >5.02</td>
#     </tr></tbody>
# </table>

# %%
strategy.initial.name = "s0"
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 6',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['soydan2006a', 'liao2005a', 'lee2008a', 'lee2009a', 'rungratri2008a']
# Forward ['soydan2012a', 'grambow2012a', 'grambow2013a']

# %% [markdown]
# ## Strategy 7 - Scopus + Sequential Snowballing  (Scopus + FS + BS)

# %%
reload()
filter_function = lambda x: x.category in ("snowball", "forward", "backward")

strategy = Strategy(*busca("scopus2016", filter_function=filter_function))
state = strategy.ffbb()

if strategy.initial.name == "s0":
    strategy.initial.name = "s0: scopus"
final = FinalSelection(state)
print("\n \033[1mProvenance Graph - Strategy 7 - Scopus + Sequential Snowballing (Scopus + FS + BS) \033[0m")

final.draw
# Out:
#  Provenance Graph - Strategy 7 - Scopus + Sequential Snowballing (Scopus + FS + BS)

# %%
#salvar(final, "E7final")

# %%
name = "Scopus + FS + BS"
df = pd.DataFrame(list(reversed(precision_recall(state, TOTAL, FINAL))))
df.columns = df.iloc[-1]
df = df.drop(df.index[-1])
last = df.iloc[-1].tolist()
strategy_row = [name] + last[11:]
array.append(strategy_row)
df

d_decimals = 4 
for coluna in ['precision', 'recall', 'fmeasure', 'accumulated_precision', 'accumulated_recall', 'accumulated_fmeasure']:
    df[coluna] = df[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df[coluna] = df[coluna].map('{:,.2f}'.format)
      
df1 = df[["state","delta_visited", "delta_related", "precision", "recall", "fmeasure", "operation", "visited", "related", "accumulated_precision", "accumulated_recall", "accumulated_fmeasure"]]
df1.columns = ['Scopus=s0 /State','Delta Visited','Delta Selected','Delta Precision%', 'Delta Recall%', 'Delta F_Measure%','Operation', 'Accumulated Visited', 'Accumulated Selected','Accumulated Precision%', 'Accumulated Recall%', 'Accumulated F_Measure%']

df1 = df1.sort_values('Scopus=s0 /State', ascending=True)
   
df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Delta Precision%': '{:,.2f}'.format,    'Delta Recall%': '{:,.2f}'.format,    'Delta F_Measure%': '{:,.2f}'.format,
    'Accumulated Precision%': '{:,.2f}'.format,    'Accumulated Recall%': '{:,.2f}'.format,    'Accumulated F_Measure%': '{:,.2f}'.format,
})


df1_style.hidden_index = True
print("\n\033[1mReport Strategy 7 - Scopus + Sequential Snowballing (Scopus + FS + BS)\033[0m")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))
print("\nPrecision = Selected/ Visited")
print("Recall = Selected/ Total of selected studies in the SLR")
print("F-Measure = Harmonic Mean of Precision and Recall")
#print (strategy_row)
df1_style
# Out:
# Report Strategy 7 - Scopus + Sequential Snowballing (Scopus + FS + BS)
#
# Total of selected studies in the SLR =  14
#
# Precision = Selected/ Visited
# Recall = Selected/ Total of selected studies in the SLR
# F-Measure = Harmonic Mean of Precision and Recall
# <style  type="text/css" >
#     #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fde th {
#           text-align: center;
#     }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col6 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col7 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col8 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col9 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col10 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col11 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col6 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col7 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col8 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col9 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col10 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow1_col11 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col6 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col7 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col8 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col9 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col10 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow2_col11 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col6 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col7 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col8 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col9 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col10 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow3_col11 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col6 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col7 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col8 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col9 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col10 {
#             text-align:  center;
#         }    #T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow4_col11 {
#             text-align:  center;
#         }</style>
# <table id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scopus=s0 /State</th>
#         <th class="col_heading level0 col1" >Delta Visited</th>
#         <th class="col_heading level0 col2" >Delta Selected</th>
#         <th class="col_heading level0 col3" >Delta Precision%</th>
#         <th class="col_heading level0 col4" >Delta Recall%</th>
#         <th class="col_heading level0 col5" >Delta F_Measure%</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accumulated Visited</th>
#         <th class="col_heading level0 col8" >Accumulated Selected</th>
#         <th class="col_heading level0 col9" >Accumulated Precision%</th>
#         <th class="col_heading level0 col10" >Accumulated Recall%</th>
#         <th class="col_heading level0 col11" >Accumulated F_Measure%</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col0" class="data row0 col0" >s0: scopus</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col1" class="data row0 col1" >79</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col2" class="data row0 col2" >3</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col3" class="data row0 col3" >3.80</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col4" class="data row0 col4" >21.43</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col5" class="data row0 col5" >6.45</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col6" class="data row0 col6" >-</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col7" class="data row0 col7" >79</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col8" class="data row0 col8" >3</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col9" class="data row0 col9" >3.80</td>
#         <td id="T_7bc8b4c2_de0e_11e8_a7aa_ac7289426fderow0_col10" class="data row0 col10" >21.43</td>
#         <td id="T_7b

# %%
dfa = pd.DataFrame(array)
df1 = dfa[[0, 2, 1, 7, 8, 9]].copy() 
df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

indexdf = df1.index[-1]
df3 = df1.loc[df1.index == indexdf] 


df3_style = df3.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df3_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df3_style.hidden_index = True
print("\n \033[1mReport Strategy 7 - Measures of Strategy (accumulated) \033[0m")
df3_style
# Out:
#  Report Strategy 7 - Measures of Strategy (accumulated)
# <style  type="text/css" >
#     #T_7dc83d14_de0e_11e8_8a41_ac7289426fde th {
#           text-align: center;
#     }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_7dc83d14_de0e_11e8_8a41_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col0" class="data row0 col0" >Scopus + FS + BS</td>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col1" class="data row0 col1" >275</td>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col2" class="data row0 col2" >9</td>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col3" class="data row0 col3" >3.27</td>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col4" class="data row0 col4" >64.29</td>
#         <td id="T_7dc83d14_de0e_11e8_8a41_ac7289426fderow0_col5" class="data row0 col5" >6.23</td>
#     </tr></tbody>
# </table>

# %%
strategy.initial.name = "s0"
sets = separa_backward_forward(state)
#sets = encontraria(strategy, state)
v = venn2(sets, set_labels = ('Backward', 'Forward'))
c = venn2_circles(sets)
plt.title(' Diagrama de Venn - Strategy 7',fontsize="14", fontweight="bold")
plt.show()

# %%
#Backward - Execução de backward em sets[0]
print("\n\033[1mReport Diagrama de Venn \033[0m\n")
print("Backward", sets[0] @ metakey)
print("Forward", sets[1] @ metakey)
# Out:
# Report Diagrama de Venn
#
# Backward ['soydan2006a', 'liao2005a', 'lee2008a', 'lee2009a', 'rungratri2008a']
# Forward ['soydan2012a']

# %% [markdown]
# # Analyses

# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.DataFrame (array)
#Esse array possui elementos do (11 ate o 23) 11o elem. até o último elem. pq estamos incluindo desde a Estrategia 1 somente esses elementos em strategy_row = [name] + last[11:].
#df.columns = ['name','related','visited','final_selected','excel','excel_selected','duplicated','accumulated_precision', 'accumulated_recall','accumulated_fmeasure','final_accumulated_precision','final_accumulated_recall','final_accumulated_fmeasure']
#df.index = df['Estratégia']
#df

df1 = df[[0, 2, 1, 7, 8, 9]].copy()  #seleção de somente alguns elementos do df do array, com posições diferentes 

df1.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']

#df1.set_index("Strategy", inplace=True)

d_decimals = 4    
for coluna in ['Precision %', 'Recall %', 'F-Measure %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)
    #df1[coluna] = df1[coluna].map('{:,.2f}'.format)

    
df1_style = (
    df1.style
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([
        dict(selector="th", props=[("text-align", "center")]),
    ])
)
df1_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

dfEAll=df1
df1_style.hidden_index = True
df1_style
# Out:
# <style  type="text/css" >
#     #T_866ed248_de0e_11e8_969e_ac7289426fde th {
#           text-align: center;
#     }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_866ed248_de0e_11e8_969e_ac7289426fderow6_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_866ed248_de0e_11e8_969e_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col0" class="data row0 col0" >Search</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col1" class="data row0 col1" >480</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col3" class="data row0 col3" >2.29</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow0_col5" class="data row0 col5" >4.45</td>
#     </tr>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col0" class="data row1 col0" >Search + SB</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col1" class="data row1 col1" >932</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col2" class="data row1 col2" >14</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col3" class="data row1 col3" >1.50</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col4" class="data row1 col4" >100.00</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow1_col5" class="data row1 col5" >2.96</td>
#     </tr>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col0" class="data row2 col0" >GS + SB</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col1" class="data row2 col1" >489</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col2" class="data row2 col2" >11</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col3" class="data row2 col3" >2.25</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col4" class="data row2 col4" >78.57</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow2_col5" class="data row2 col5" >4.37</td>
#     </tr>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col0" class="data row3 col0" >Scopus + SB</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col1" class="data row3 col1" >502</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col2" class="data row3 col2" >11</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col3" class="data row3 col3" >2.19</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col4" class="data row3 col4" >78.57</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow3_col5" class="data row3 col5" >4.26</td>
#     </tr>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col0" class="data row4 col0" >Scopus + BS // FS</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col1" class="data row4 col1" >242</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col2" class="data row4 col2" >9</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col3" class="data row4 col3" >3.72</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col4" class="data row4 col4" >64.29</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow4_col5" class="data row4 col5" >7.03</td>
#     </tr>    <tr>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow5_col0" class="data row5 col0" >Scopus + BS + FS</td>
#         <td id="T_866ed248_de0e_11e8_969e_ac7289426fderow5_col1" class="data row5 col1" >424</td>

# %%
import matplotlib.pyplot as plt
exclude = ['Related', 'Visited', 'Final Selected']

ax = df1.loc[:, df1.columns.difference(exclude)].plot.bar(y=['Precision %', 'Recall %', 'F-Measure %'],alpha=0.75,  rot=60 )
ax.set_title("Precision, Recall and F-Measure of Hybrid Strategies\n")
ax.legend(loc = 'best')
ax.get_legend().set_bbox_to_anchor((1.3, 1.0))
ax.set_xticklabels(df1['Strategy'])

plt.xlabel("\nStrategy")
plt.ylabel("Percent (%)\n")
plt.tight_layout()

print ('\n \033[1m Bar Chart Strategies \033[0m')
# Out:
#   Bar Chart Strategies

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=False)

df1.plot.bar(y=['Precision %'], color="navy", alpha=0.75, rot=60, ax=ax1)
ax = ax1
ax.set_title("Precision of Hybrid Strategies\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Strategy'])
ax.set_ylabel("Percent (%)")
print ('\n \033[1m Bar Chart Strategies\033[0m')


df1.plot.bar(y=['Recall %'], color="green", alpha=0.75, rot=60, ax=ax2)
ax = ax2
ax.set_title("Recall of Hybrid Strategies\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Strategy'])
ax.set_xlabel("\nStrategy")
ax.set_ylabel("Percent (%)")

df1.plot.bar(y=['F-Measure %'], color="crimson", alpha=0.75, rot=60, ax=ax3)
ax = ax3
ax.set_title("F-Measure of Hybrid Strategies\n")
ax.legend_.remove()
ax.set_xticklabels(df1['Strategy'])
ax.set_ylabel("Percent (%)")
ax.grid(False)
f.set_size_inches(15, 4)

f.savefig("measurestrategies.png")
# Out:
#   Bar Chart Strategies

# %%
#import matplotlib.pyplot as plt
#exclude = ['Related', 'Visited', 'Final Selected']

#ax = df1.loc[:, df1.columns.difference(exclude)].plot.bar(y=['Precision %'], color = "blue", alpha=0.75, rot=60 )
#ax.set_title("Precision of Hybrid Strategies\n")
#ax.set_xticklabels(df1['Strategy'])
#ax.legend_.remove()
#plt.xlabel("\nStrategy")
#plt.ylabel("Percent (%)\n")
#plt.tight_layout()

#print ('\n \033[1m Bar Chart Strategies \033[0m')

# %%
#import matplotlib.pyplot as plt
#exclude = ['Related', 'Visited', 'Final Selected']

#ax = df1.loc[:, df1.columns.difference(exclude)].plot.bar(y=['Recall %'], color = "orange", alpha=0.75, rot=60 )
#ax.set_title("Recall of Hybrid Strategies\n")
#ax.set_xticklabels(df1['Strategy'])
#ax.legend_.remove()
#plt.xlabel("\nStrategy")
#plt.ylabel("Percent (%)\n")
#plt.tight_layout()

#print ('\n \033[1m Bar Chart Strategies \033[0m')

# %%
#import matplotlib.pyplot as plt
#exclude = ['Related', 'Visited', 'Final Selected']

#ax = df1.loc[:, df1.columns.difference(exclude)].plot.bar(y=['F-Measure %'], color = "green", alpha=0.75, rot=60 )
#ax.set_title("F-Measure of Hybrid Strategies\n")
#ax.set_xticklabels(df1['Strategy'])
#ax.legend_.remove()
#plt.xlabel("\nStrategy")
#plt.ylabel("Percent (%)\n")
#plt.tight_layout()

#print ('\n \033[1m Bar Chart Strategies \033[0m')

# %%
#df.to_csv("estrategias.csv")
df.to_excel("estrategias.xlsx")

# %% [markdown]
# # Research Questions

# %%
print ("\nRQ1) Which of the digital libraries used in the published SLR is more efficient?")

#RQ1.1) Qual busca em biblioteca digital encontra mais artigos incluídos na lista de selecionados da SLR 
#publicada dentre o resultado retornado na busca (Precision)?
#RQ1.2) Qual busca em biblioteca digital recupera todos os artigos que estavam incluídos na lista de 
#selecionados da SRL publicada (Recall)?
#RQ1.3) Qual biblioteca digital apresenta melhor média harmônica (F-Measure)?

dfE1r

df1_style = dfE1r.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df1_style.hidden_index = True
df1_style
# Out:
# RQ1) Which of the digital libraries used in the published SLR is more efficient?
# <style  type="text/css" >
#     #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fde th {
#           text-align: center;
#     }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow6_col5 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col0 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col1 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col2 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col3 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col4 {
#             text-align:  center;
#         }    #T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow7_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Digital Library</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col0" class="data row0 col0" >acm</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col1" class="data row0 col1" >0</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col2" class="data row0 col2" >0</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col3" class="data row0 col3" >nan</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col4" class="data row0 col4" >0.00</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow0_col5" class="data row0 col5" >0.00</td>
#     </tr>    <tr>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col0" class="data row1 col0" >googlescholar</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col1" class="data row1 col1" >466</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col2" class="data row1 col2" >11</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col3" class="data row1 col3" >2.36</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col4" class="data row1 col4" >78.57</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow1_col5" class="data row1 col5" >4.58</td>
#     </tr>    <tr>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col0" class="data row2 col0" >ieee</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col1" class="data row2 col1" >0</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col2" class="data row2 col2" >0</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col3" class="data row2 col3" >nan</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col4" class="data row2 col4" >0.00</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow2_col5" class="data row2 col5" >0.00</td>
#     </tr>    <tr>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col0" class="data row3 col0" >sciencedirect</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col1" class="data row3 col1" >21</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col2" class="data row3 col2" >0</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col3" class="data row3 col3" >0.00</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col4" class="data row3 col4" >0.00</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow3_col5" class="data row3 col5" >0.00</td>
#     </tr>    <tr>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col0" class="data row4 col0" >scopus</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col1" class="data row4 col1" >79</td>
#         <td id="T_d3d2d12c_de0e_11e8_b1c1_ac7289426fderow4_col2" class="

# %%
print ("\nRQ2) Which of the hybrid strategies is more efficient?")

#RQ2.1)A estratégia híbrida envolve analisar menos artigos quando comparada 
#com as SLRs publicadas que conduziram buscas somente em bases de dados? Precision.
#RQ2.2)A estratégia híbrida recupera todos os artigos que estavam incluídos 
#na SLR publicada que conduziu as buscas em bases de dados? Recall.
#RQ2.3)Qual estratégia híbrida apresenta melhor média harmônica? F-measure.


dfEAll

df1 = dfEAll.drop(dfEAll.index[[0]])

exclude = ['Final Selected']
df1 = df1.loc[:, dfEAll.columns.difference(exclude)]

df2 = df1[['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']]      
df2.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']
df1_style = df2.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])

df1_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})

df1_style.hidden_index = True
df1_style
# Out:
# RQ2) Which of the hybrid strategies is more efficient?
# <style  type="text/css" >
#     #T_d474c3a4_de0e_11e8_96b0_ac7289426fde th {
#           text-align: center;
#     }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_d474c3a4_de0e_11e8_96b0_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col0" class="data row0 col0" >Search + SB</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col1" class="data row0 col1" >932</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col2" class="data row0 col2" >14</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col3" class="data row0 col3" >1.50</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col4" class="data row0 col4" >100.00</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow0_col5" class="data row0 col5" >2.96</td>
#     </tr>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col0" class="data row1 col0" >GS + SB</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col1" class="data row1 col1" >489</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col2" class="data row1 col2" >11</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col3" class="data row1 col3" >2.25</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col4" class="data row1 col4" >78.57</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow1_col5" class="data row1 col5" >4.37</td>
#     </tr>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col0" class="data row2 col0" >Scopus + SB</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col1" class="data row2 col1" >502</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col2" class="data row2 col2" >11</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col3" class="data row2 col3" >2.19</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col4" class="data row2 col4" >78.57</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow2_col5" class="data row2 col5" >4.26</td>
#     </tr>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col0" class="data row3 col0" >Scopus + BS // FS</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col1" class="data row3 col1" >242</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col2" class="data row3 col2" >9</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col3" class="data row3 col3" >3.72</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col4" class="data row3 col4" >64.29</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow3_col5" class="data row3 col5" >7.03</td>
#     </tr>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col0" class="data row4 col0" >Scopus + BS + FS</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col1" class="data row4 col1" >424</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col2" class="data row4 col2" >11</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col3" class="data row4 col3" >2.59</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col4" class="data row4 col4" >78.57</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow4_col5" class="data row4 col5" >5.02</td>
#     </tr>    <tr>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col0" class="data row5 col0" >Scopus + FS + BS</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col1" class="data row5 col1" >275</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col2" class="data row5 col2" >9</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col3" class="data row5 col3" >3.27</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col4" class="data row5 col4" >64.29</td>
#         <td id="T_d474c3a4_de0e_11e8_96b0_ac7289426fderow5_col5" class="data row5 col5" >6.23</td>
#     </tr></tbody>
# </table>

# %%
print ("\nRQ3) Which of the strategies is more efficient?")

#RQ3.1)A estratégia envolve analisar menos artigos quando comparada 
#com as SLRs publicadas que conduziram buscas somente em bases de dados? Precision.
#RQ3.2)A estratégia recupera todos os artigos que estavam incluídos 
#na SLR publicada que conduziu as buscas em bases de dados? Recall.
#RQ3.3) Qual estratégia apresenta melhor média harmônica? F-measure.

dfEAll
exclude = ['Final Selected']
df1 = dfEAll.loc[:, dfEAll.columns.difference(exclude)]
df2 = df1[['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']]      
df2.columns = ['Strategy','Visited', 'Selected','Precision %', 'Recall %', 'F-Measure %']
df1_style = df2.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])
df1_style.format({
    'Precision %': '{:,.2f}'.format,    'Recall %': '{:,.2f}'.format,    'F-Measure %': '{:,.2f}'.format,
})
df1_style.hidden_index = True
df1_style
# Out:
# RQ3) Which of the strategies is more efficient?
# <style  type="text/css" >
#     #T_d51f5b18_de0e_11e8_97b0_ac7289426fde th {
#           text-align: center;
#     }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col5 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col3 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col4 {
#             text-align:  center;
#         }    #T_d51f5b18_de0e_11e8_97b0_ac7289426fderow6_col5 {
#             text-align:  center;
#         }</style>
# <table id="T_d51f5b18_de0e_11e8_97b0_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Strategy</th>
#         <th class="col_heading level0 col1" >Visited</th>
#         <th class="col_heading level0 col2" >Selected</th>
#         <th class="col_heading level0 col3" >Precision %</th>
#         <th class="col_heading level0 col4" >Recall %</th>
#         <th class="col_heading level0 col5" >F-Measure %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col0" class="data row0 col0" >Search</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col1" class="data row0 col1" >480</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col2" class="data row0 col2" >11</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col3" class="data row0 col3" >2.29</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col4" class="data row0 col4" >78.57</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow0_col5" class="data row0 col5" >4.45</td>
#     </tr>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col0" class="data row1 col0" >Search + SB</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col1" class="data row1 col1" >932</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col2" class="data row1 col2" >14</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col3" class="data row1 col3" >1.50</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col4" class="data row1 col4" >100.00</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow1_col5" class="data row1 col5" >2.96</td>
#     </tr>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col0" class="data row2 col0" >GS + SB</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col1" class="data row2 col1" >489</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col2" class="data row2 col2" >11</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col3" class="data row2 col3" >2.25</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col4" class="data row2 col4" >78.57</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow2_col5" class="data row2 col5" >4.37</td>
#     </tr>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col0" class="data row3 col0" >Scopus + SB</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col1" class="data row3 col1" >502</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col2" class="data row3 col2" >11</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col3" class="data row3 col3" >2.19</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col4" class="data row3 col4" >78.57</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow3_col5" class="data row3 col5" >4.26</td>
#     </tr>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col0" class="data row4 col0" >Scopus + BS // FS</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col1" class="data row4 col1" >242</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col2" class="data row4 col2" >9</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col3" class="data row4 col3" >3.72</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col4" class="data row4 col4" >64.29</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow4_col5" class="data row4 col5" >7.03</td>
#     </tr>    <tr>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col0" class="data row5 col0" >Scopus + BS + FS</td>
#         <td id="T_d51f5b18_de0e_11e8_97b0_ac7289426fderow5_col1" class="data row5 col1" >424</td>

# %%
print ("\nRQ4) How many selected articles does the digital library find through the direct search for the title of the article?")
print("\nTotal of selected studies in the SLR = ", len(TOTAL))

df = pd.DataFrame (arraysearch)
df1 = df[[0, 1, 2]] 
df1.columns = ['Digital Library','Selected','Recall %']

df1 = df1.sort_values('Digital Library', ascending=True)

d_decimals = 4    
for coluna in ['Recall %']:
    df1[coluna] = df1[coluna].apply(lambda x: round(x,d_decimals)*100)

df1_style = df1.style.set_properties(**{'text-align': 'center'}).set_table_styles([
    dict(selector="th", props=[("text-align", "center")]),
])
df1_style.format({
    'Recall %': '{:,.2f}'.format,
})
df1_style.hidden_index = True
df1_style
# Out:
# RQ4) How many selected articles does the digital library find through the direct search for the title of the article?
#
# Total of selected studies in the SLR =  14
# <style  type="text/css" >
#     #T_d6f50230_de0e_11e8_9f17_ac7289426fde th {
#           text-align: center;
#     }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col2 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col0 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col1 {
#             text-align:  center;
#         }    #T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col2 {
#             text-align:  center;
#         }</style>
# <table id="T_d6f50230_de0e_11e8_9f17_ac7289426fde" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Digital Library</th>
#         <th class="col_heading level0 col1" >Selected</th>
#         <th class="col_heading level0 col2" >Recall %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col0" class="data row0 col0" >acm</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col1" class="data row0 col1" >0</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow0_col2" class="data row0 col2" >0.00</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col0" class="data row1 col0" >googlescholar</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col1" class="data row1 col1" >14</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow1_col2" class="data row1 col2" >100.00</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col0" class="data row2 col0" >ieee</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col1" class="data row2 col1" >3</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow2_col2" class="data row2 col2" >21.43</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col0" class="data row3 col0" >sciencedirect</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col1" class="data row3 col1" >1</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow3_col2" class="data row3 col2" >7.14</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col0" class="data row4 col0" >scopus</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col1" class="data row4 col1" >7</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow4_col2" class="data row4 col2" >50.00</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col0" class="data row5 col0" >springer</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col1" class="data row5 col1" >3</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow5_col2" class="data row5 col2" >21.43</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col0" class="data row6 col0" >webofscience</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col1" class="data row6 col1" >5</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow6_col2" class="data row6 col2" >35.71</td>
#     </tr>    <tr>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col0" class="data row7 col0" >wiley</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col1" class="data row7 col1" >0</td>
#         <td id="T_d6f50230_de0e_11e8_9f17_ac7289426fderow7_col2" class="data row7 col2" >0.00</td>
#     </tr></tbody>
# </table>
